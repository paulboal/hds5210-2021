# %% [markdown]
# # Week 6 Exercises
#
# _McKinney 6.1_
#
# There are multiple ways to solve the problems below.  You can use any one of several approaches.  For example, you can read CSV files using Pandas or the csv module.  Your score won't depend on which modules you choose to use unless explicitly noted below, but your programming style will still matter.

# %% [markdown]
# ### 30.1 List of Allergies
#
# In the /data directory on the Jupyter server, there is a file called `allergies.json` that contains a list of patient allergies.  It is taken from sample data provided by the EHR vendor, Epic, here: https://open.epic.com/Clinical/Allergy
#
# Take some time to look at the structure of the file.  You can open it directly in Jupyter by clicking the _Home_ icon, then the _from_instructor_ folder, and then the _data_ folder.
#
# Within the file, you'll see that it is a dictionary with many items in it.  One of those items is called `entry` and that item is a list of things.  You can tell that because the item name is immediately followed by an opening square bracket, signifying the start of a list.  It's line 11 of the file: `  "entry": [`
#
# Write a function named `allergy_count(json_file)` that takes as one parameter the name of the JSON file and returns an integer number of entries in that file.  Your function should open the file, read the json into a Python object, and return how many items there are in the list of `entry`s.

# %%
import json
from pathlib import Path
HOME = str(Path.home())

ALLERGIES_FILE="/data/allergies.json"

# %%
### BEGIN SOLUTION
def allergy_count(json_file):
    """(str)->int
    This function takes a file name and reads the JSON from that
    file.  It assumes the file structure contains a dictionary
    with a key of 'entry' whose value is a list of allergies.
    
    This function returns the length of that list of entries."""
    
    with open(json_file) as f:
        allergies = json.load(f)
    
    return len(allergies['entry'])

### END SOLUTION

# %%
### BEGIN SOLUTION
def allergy_count(json_file):
    with open(json_file) as f:
        allergies = json.load(f)
        
    return(len(allergies.get('entry')))
### END SOLUTION

# %%
allergy_count(ALLERGIES_FILE)
# Out:
# 4

# %%
assert type(allergy_count(ALLERGIES_FILE)) == int
assert allergy_count(ALLERGIES_FILE) == 4

# %% [markdown]
# ### 30.2 Number of Patients
#
# If you dig a little bit deaper into this list of allergies, you'll see that each result has a patient associated with it.  Create a funcation called `patient_count(json_file)` that will count how many unique patients we have in this JSON structure.

# %%
with open(ALLERGIES_FILE) as f:
    allergies = json.load(f)

# %%
entry = allergies.get('entry')[0]

# %%
patient = entry.get('resource').get('patient').get('display')
print(patient)
# Out:
# Jason Argonaut

# %%
### BEGIN SOLUTION

def patient_count(json_file):
    """(str)->int
    This function reads the JSON-structured information from the file
    and identifies how many different (unique) patients for which there
    are allergies.  This function returns the number of unique patients.
    """
    
    with open(json_file) as f:
        allergies = json.load(f)
    
    patients = set()
    
    for allergy in allergies.get('entry'):
        patient = allergy.get('resource').get('patient').get('display')
        patients.add(patient)

    return len(patients)

### END SOLUTION

# %%
### BEGIN SOLUTION
def patient_count(json_file):
    patients = set()
    with open(json_file) as f:
        allergies = json.load(f)
        
    for entry in allergies.get('entry'):
        resource = entry.get('resource')
        patient = resource.get('patient')
        name = patient.get('display')
        patients.add(name)
        
    return patients
### END SOLUTION

# %%
patient_count(ALLERGIES_FILE)
# Out:
# 2

# %% [markdown]
# ### 30.3 How Many Allergies per Patient
#
# Although each entry is a separate allergy, several of them are for the same patient.  Write a function called `allergy_per_patient(json_file)` that counts up how many allergies each patient has.

# %%
### BEGIN SOLUTION

def allergy_per_patient(json_file):
    """(str)->dict
    """
    
    with open(json_file) as f:
        allergies = json.load(f)
    
    patient_allergies = {}
    
    for allergy in allergies.get('entry'):
        patient = allergy.get('resource').get('patient').get('display')
        if patient in patient_allergies:
            patient_allergies[patient] += 1
        else:
            patient_allergies[patient] = 1

    return patient_allergies
### END SOLUTION

# %%
### BEGIN SOLUTION
def allergy_per_patient(json_file):
    patients = {}
    with open(json_file) as f:
        allergies = json.load(f)
        
    for entry in allergies.get('entry'):
        resource = entry.get('resource')
        patient = resource.get('patient')
        name = patient.get('display')
        patients[name] = patients.setdefault(name,0) + 1
        
    return patients
### END SOLUTION

# %%
allergy_per_patient(ALLERGIES_FILE)
# Out:
# {'Jason Argonaut': 3, 'Paul Boal': 1}

# %%
{
    "Paul Boal": 1,
    "Jason Argonaut": 3
}
# Out:
# {}

# %% [markdown]
# ### 30.4 Patient Allergies and Reaction
#
# You'll see in the file that each of the items in the `entry` list have several other attributes including a patient name, substance text representation, and a reaction manifestation.  Create a function named `allergy_list(json_file)` that will create an output list that has patient name, allergy, and reaction for each `entry`.  The actual result you should get will be:
#
# ```python
# [['Jason Argonaut', 'PENICILLIN G', 'Hives'],
#  ['Paul Boal', 'PENICILLIN G', 'Bruising'],
#  ['Jason Argonaut', 'SHELLFISH-DERIVED PRODUCTS', 'Itching'],
#  ['Jason Argonaut', 'STRAWBERRY', 'Anaphylaxis']]
# ```
#
# You'll notice that the reaction and the manifestation of that action are lists.  You only need to capture the first reaction and the first manifestation of the action.  That is, if there is a list of things, just output the first one.

# %%
import json

### BEGIN SOLUTION
### END SOLUTION

# %%
output=[['Jason Argonaut', 'PENICILLIN G', 'Hives'],
 ['Paul Boal', 'PENICILLIN G', 'Bruising'],
 ['Jason Argonaut', 'SHELLFISH-DERIVED PRODUCTS', 'Itching'],
 ['Jason Argonaut', 'STRAWBERRY', 'Anaphylaxis']]

assert allergy_list(ALLERGIES_FILE) == output

# %% [markdown]
# ### 30.5 Allergy Reaction
#
# Write a function called `allergy_reaction(json_file,patient,substance)` that takes three parameter and returns the reaction that will happen if the patient takes the specified substance.  Solve this, in part, by calling your `allergy_list` function inside your new `allergy_reaction` function.
#
# If the substance is not found in the allergy list, the function should return None.

# %%
import json

### BEGIN SOLUTION
### END SOLUTION

# %%
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'PENICILLIN G') == 'Hives'
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'SHELLFISH-DERIVED PRODUCTS') == 'Itching'
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'STRAWBERRY') == 'Anaphylaxis'
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'PENICILLIN') == None
assert allergy_reaction(ALLERGIES_FILE, 'Paul Boal', 'PENICILLIN G') == 'Bruising'

# %% [markdown]
# ---
# ---
#
# # Stretch (Extra) Problems
#
# Work on either of the stretch problems below can earn you up to 25 free points toward the midterm assignment.  That is, if you complete one of these extra problems successfully, you can skip 1 of the problems that will appear on the midterm exam coming up next week.
#
# The midterm will be distribute this Saturday 3/13.
#
# This assignment is due on Sunday 3/14.  If you are trying for one of these extra problems Slack me, and I'll provide you feedback on how you did on these before end of day Monday 3/15.  That way you can choose what to complete on the midterm.

# %% [markdown]
# ---
# ---
#
# ### STRETCH for March 2021 - For those looking for an additional challenge
#
# As I've mentioned in class, CMS is now enforcing a rule around price transparency.  Every facility that take Medicare payments is required to publish a "machine readable" file with it's pricing infomration for a number of common procedures across all of the payers they work with.  There are two examples of such files in the `/data/` directory: `whiteriver.json` and `saline.xml`.
#
# If you want to compare contracted prices across these two hospitals, you'll need to read in the information from both of those files into some kind of data structure, then merge the data together from those two files.  See what you can do.
#
# See if you can create an output file that has the following fields:
# * HOSPITAL
# * PROCEDURE_CODE
# * PAYER
# * AMOUNT
#
# If you choose to work on this, you may get stuck at some point and you won't know if you're _doing it right_. Make some assumptions. Document your questions in this notebook.

# %% [markdown]
# ```
# Procedure Code |  Description  |  Gross Charges  |  Aetna  |  QualChoice
# ```

# %%
import json

with open('whiteriver.json') as f:
    whiteriver = json.load(f)

# %%
wr_charges = {}
for charge in whiteriver.get('root').get('StandardCharges'):
    procedure = charge.get('ProcedureCode')
    description = charge.get('Description')
    gross_charges = float(charge.get('OutpatientGrossCharge'))
    aetna = float(charge.get('AETNA_Outpatient'))
    qualchoice = float(charge.get('QUALCHOICE_Outpatient'))
    wr_charges[('whiteriver',procedure)] = [description, gross_charges, aetna, qualchoice]

# %%
wr_charges[('whiteriver','00170')]
# Out:
# ['ANESTH PROCEDURE ON MOUTH', 9546.58, 8400.9904, 5346.0848]

# %%
wr_charges.keys()
# Out:
# dict_keys([('whiteriver', '00170'), ('whiteriver', '00220'), ('whiteriver', '01996'), ('whiteriver', '10004'), ('whiteriver', '10005'), ('whiteriver', '10006'), ('whiteriver', '10007'), ('whiteriver', '10008'), ('whiteriver', '10009'), ('whiteriver', '10010'), ('whiteriver', '10011'), ('whiteriver', '10012'), ('whiteriver', '10021'), ('whiteriver', '10030'), ('whiteriver', '10060'), ('whiteriver', '10061'), ('whiteriver', '10120'), ('whiteriver', '10140'), ('whiteriver', '10160'), ('whiteriver', '11010'), ('whiteriver', '11011'), ('whiteriver', '11012'), ('whiteriver', '11042'), ('whiteriver', '11043'), ('whiteriver', '11044'), ('whiteriver', '11045'), ('whiteriver', '11046'), ('whiteriver', '11047'), ('whiteriver', '11055'), ('whiteriver', '11056'), ('whiteriver', '11057'), ('whiteriver', '11102'), ('whiteriver', '11103'), ('whiteriver', '11104'), ('whiteriver', '11105'), ('whiteriver', '11106'), ('whiteriver', '11107'), ('whiteriver', '11200'), ('whiteriver', '11300'), ('whiteriver', '11400'), ('whiteriver', '11401'), ('whiteriver', '11402'), ('whiteriver', '11403'), ('whiteriver', '11404'), ('whiteriver', '11406'), ('whiteriver', '11420'), ('whiteriver', '11421'), ('whiteriver', '11422'), ('whiteriver', '11442'), ('whiteriver', '11462'), ('whiteriver', '11602'), ('whiteriver', '11621'), ('whiteriver', '11622'), ('whiteriver', '11623'), ('whiteriver', '11641'), ('whiteriver', '11719'), ('whiteriver', '11721'), ('whiteriver', '11730'), ('whiteriver', '11732'), ('whiteriver', '11750'), ('whiteriver', '11760'), ('whiteriver', '11765'), ('whiteriver', '11771'), ('whiteriver', '11900'), ('whiteriver', '12001'), ('whiteriver', '12002'), ('whiteriver', '12011'), ('whiteriver', '12031'), ('whiteriver', '12032'), ('whiteriver', '12034'), ('whiteriver', '12052'), ('whiteriver', '13100'), ('whiteriver', '13121'), ('whiteriver', '13131'), ('whiteriver', '13132'), ('whiteriver', '13151'), ('whiteriver', '13152'), ('whiteriver', '13160'), ('whiteriver', '15002'), ('whiteriver', '15271'), ('whiteriver', '15273'), ('whiteriver', '15274'), ('whiteriver', '15275'), ('whiteriver', '15276'), ('whiteriver', '15277'), ('whiteriver', '15278'), ('whiteriver', '15576'), ('whiteriver', '15777'), ('whiteriver', '16020'), ('whiteriver', '16025'), ('whiteriver', '16030'), ('whiteriver', '17000'), ('whiteriver', '17003'), ('whiteriver', '17004'), ('whiteriver', '17110'), ('whiteriver', '17250'), ('whiteriver', '19000'), ('whiteriver', '19001'), ('whiteriver', '19020'), ('whiteriver', '19081')])

# %%
from lxml import objectify

with open('saline.xml') as f:
    saline = objectify.parse(f)

# %%
xml=saline.getroot()
facility = xml.find('Facility')
outpatient = facility.findall('Patient')[2]

# %%
sal_charges={}

for charge in outpatient.findall('Charge'):
    charge_type = charge.attrib['Type']
    for item in charge.findall('Item'):
        aetna = None
        qualchoice = None
        code = item.attrib['Code']
        description = item.find('Description').text
        gross_charges = float(item.find('GrossCharge').text)
        for contract in item.find('Contracts').findall('Contract'):
            payer = contract.attrib['Payer']
            charge = contract.attrib['Charge']
            if payer == "AETNA - (POS)":
                aetna = float(charge)
            elif payer == "QUALCHOICE LIFE AND HEALTH INSURANCE COMPANY INC - (Indemnity)":
                qualchoice = float(charge)
        # print(code, gross_charges, aetna, qualchoice)
        sal_charges[('saline',code)] = [description, gross_charges, aetna, qualchoice]

# %%
sal_charges
# Out:
# {('saline', '10060'): ['DRAINAGE OF SKIN ABSCESS', 3406.7896, 129.19, 1274.0],
#  ('saline', '10061'): ['DRAINAGE OF SKIN ABSCESS', 3057.258571, None, None],
#  ('saline', '10081'): ['DRAINAGE OF PILONIDAL CYST', 10689.97, None, None],
#  ('saline', '10120'): ['REMOVE FOREIGN BODY', 5229.0, None, None],
#  ('saline', '10140'): ['DRAINAGE OF HEMATOMA/FLUID', 4236.7, None, None],
#  ('saline', '10160'): ['PUNCTURE DRAINAGE OF LESION', 878.0, None, None],
#  ('saline', '10180'): ['COMPLEX DRAINAGE WOUND', 6049.0, None, None],
#  ('saline', '11010'): ['DEBRIDE SKIN AT FX SITE', 5871.153333, None, None],
#  ('saline', '11011'): ['DEBRIDE SKIN MUSC AT FX SITE', 3615.5, None, None],
#  ('saline', '11042'): ['DEB SUBQ TISSUE 20 SQ CM/<', 878.0, None, 836.0],
#  ('saline', '11043'): ['DEB MUSC/FASCIA 20 SQ CM/<', 2087.509375, None, None],
#  ('saline', '11044'): ['DEB BONE 20 SQ CM/<', 6192.24, None, None],
#  ('saline', '11055'): ['TRIM SKIN LESION', 493.0, None, None],
#  ('saline', '11056'): ['TRIM SKIN LESIONS 2 TO 4', 493.0, None, None],
#  ('saline', '11400'): ['EXC TR-EXT B9+MARG 0.5 CM<',
#   4354.395833,
#   461.083333,
#   None],
#  ('saline', '11401'): ['EXC TR-EXT B9+MARG 0.6-1 CM', 4382.793333, None, None],
#  ('saline', '11402'): ['EXC TR-EXT B9+MARG 1.1-2 CM',
#   3713.400909,
#   216.75,
#   None],
#  ('saline', '11403'): ['EXC TR-EXT B9+MARG 2.1-3CM', 3971.928888, 289.0, None],
#  ('saline', '11404'): ['EXC TR-EXT B9+MARG 3.1-4 CM', 3293.79, None, None],
#  ('saline', '11406'): ['EXC TR-EXT B9+MARG >4.0 CM', 5415.72, None, None],
#  ('saline', '11420'): ['EXC H-F-NK-SP B9+MARG 0.5/<', 3111.8, None, None],
#  ('saline', '11421'): ['EXC H-F-NK-SP B9+MARG 0.6-1', 2139.33, None, None],
#  ('saline', '11422'): ['EXC H-F-NK-SP B9+MARG 1.1-2', 3569.366, None, None],
#  ('saline', '11423'): ['EXC H-F-NK-SP B9+MARG 2.1-3', 6418.0, None, None],
#  ('saline', '11424'): ['EXC H-F-NK-SP B9+MARG 3.1-4', 5270.0, None, None],
#  ('saline', '11440'): ['EXC FACE-MM B9+MARG 0.5 CM/<', 4984.5, None, None],
#  ('saline', '11446'): ['EXC FACE-MM B9+MARG >4 CM', 6172.0, None, None],
#  ('saline', '11450'): ['REMOVAL SWEAT GLAND LESION', 5229.0, None, None],
#  ('saline', '11600'): ['EXC TR-EXT MAL+MARG 0.5 CM/<', 4782.75, 289.0, None],
#  ('saline', '11601'): ['EXC TR-EXT MAL+MARG 0.6-1 CM', 2922.0, None, None],
#  ('saline', '11602'): ['EXC TR-EXT MAL+MARG 1.1-2 CM', 3757.75, None, None],
#  ('saline', '11623'): ['EXC S/N/H/F/G MAL+MRG 2.1-3', 6213.0, None, None],
#  ('saline', '11642'): ['EXC F/E/E/N/L MAL+MRG 1.1-2', 2922.0, None, None],
#  ('saline', '11740'): ['DRAIN BLOOD FROM UNDER NAIL', 1455.0, None, None],
#  ('saline', '11750'): ['REMOVAL OF NAIL BED', 1302.55, None, None],
#  ('saline', '11760'): ['REPAIR OF NAIL BED', 3725.75, None, None],
#  ('saline', '11770'): ['REMOVE PILONIDAL CYST SIMPLE', 5576.79625, None, None],
#  ('saline', '11772'): ['REMOVE PILONIDAL CYST COMPL', 6131.0, None, None],
#  ('saline', '11982'): ['REMOVE DRUG IMPLANT DEVICE', 5156.5, 289.0, None],
#  ('saline', '12001'): ['RPR S/N/AX/GEN/TRNK 2.5CM/<', 1181.965932, None, None],
#  ('saline', '12002'): ['RPR S/N/AX/GEN/TRNK2.6-7.5CM',
#   1145.854848,
#   None,
#   None],
#  ('saline', '12004'): ['RPR S/N/AX/GEN/TRK7.6-12.5CM', 1650.0, None, None],
#  ('saline', '12005'): ['RPR S/N/A/GEN/TRK12.6-20.0CM',
#   1577.333333,
#   None,
#   None],
#  ('saline', '12011'): ['RPR F/E/E/N/L/M 2.5 CM/<', 1763.839268, None, None],
#  ('saline', '12013'): ['RPR F/E/E/N/L/M 2.6-5.0 CM', 1650.0, None, None],
#  ('saline', '12020'): ['CLOSURE OF SPLIT WOUND', 5847.0, None, None],
#  ('saline', '12031'): ['INTMD RPR S/A/T/EXT 2.5 CM/<', 3360.0, None, None],
#  ('saline', '12032'): ['INTMD RPR S/A/T/EXT 2.6-7.5', 2228.7425, None, None],
#  ('saline', '12034'): ['INTMD RPR S/TR/EXT 7.6-12.5', 5014.75, None, None],
#  ('saline', '12036'): ['INTMD RPR S/A/T/EXT 20.1-30', 550.0, None, None],
#  ('saline', '12051'): ['INTMD RPR FACE/MM 2.5 CM/<', 1359.105, None, None],
#  ('saline', '12052'): ['INTMD RPR FACE/MM 2.6-5.0 CM', 2684.42, None, None],
#  ('saline', '13120'): ['CMPLX RPR S/A/L 1.1-2.5 CM', 10638.09, None, None],
#  ('saline', '13160'): ['LATE CLOSURE OF WOUND', 7003.135, None, None],
#  ('saline', '14350'): ['FILLETED FINGER/TOE FLAP', 8676.91, None, None],
#  ('saline', '15002'): ['WOUND PREP TRK/ARM/LEG', 13195.12, None, None],
#  ('saline', '15004'): ['WOUND PREP F/N/HF/G', 3654.756052, None, None],
#  ('saline', '15271'): ['SKIN SUB GRAFT TRNK/ARM/LEG', 16478.71, None, None],
#  ('saline', '15275'): ['SKIN SUB GRAFT FACE/NK/HF/G', 4327.0, None, None],
#  ('saline', '15830'): ['EXC SKIN ABD', 18388.0, None, None],
#  ('saline', '16020'): ['DRESS/DEBRID P-THICK BURN S', 1154.25, None, None],
#  ('saline', '17110'): ['DESTRUCT B9 LESION 1-14', 492.0, None, None],
#  ('saline', '17250'): ['CHEM CAUT OF GRANLTJ TISSUE', 492.0, None, None],
#  ('saline', '19000'): ['DRAINAGE OF BREAST LESION', 1618.0, None, None],
#  ('saline', '19083'): ['BX BREAST 1ST LESION US IMAG', 3843.0, None, None],
#  ('saline', '19120'): ['REMOVAL OF BREAST LESION', 7403.993333, None, None],
#  ('saline', '20205'): ['DEEP MUSCLE BIOPSY', 9213.21, None, None],
#  ('saline', '20206'): ['NEEDLE BIOPSY MUSCLE', 3843.0, None, None],
#  ('saline', '20225'): ['BONE BIOPSY TROCAR/NEEDLE', 3843.0, None, None],
#  ('saline', '20501'): ['INJECT SINUS TRACT FOR X-RAY', 184.0, None, None],
#  ('saline', '20520'): ['REMOVAL OF FOREIGN BODY', 4819.0, None, None],
#  ('saline', '20525'): ['REMOVAL OF FOREIGN BODY', 5106.0, None, None],
#  ('saline', '20550'): ['INJ TENDON SHEATH/LIGAMENT', 6178.32, None, None],
#  ('saline', '20605'): ['DRAIN/INJ JOINT/BURSA W/O US', 6799.0, None, None],
#  ('saline', '20610'): ['DRAIN/INJ JOINT/BURSA W/O US', 5583.74, None, None],
#  ('saline', '20680'): ['REMOVAL OF SUPPORT IMPLANT', 7263.834, None, None],
#  ('saline', '20924'): ['REMOVAL OF TENDON FOR GRAFT', 17120.45, None, None],
#  ('saline', '20999'): ['MUSCULOSKELETAL SURGERY', 8176.625, None, None],
#  ('saline', '21315'): ['CLOSED TX NOSE FX W/O STABLJ', 4163.0, None, None],
#  ('saline', '21320'): ['CLOSED TX NOSE FX W/ STABLJ', 4409.0, None, None],
#  ('saline', '22511'): ['PERQ LUMBOSACRAL INJECTION', 7328.0, None, None],
#  ('saline', '23120'): ['PARTIAL REMOVAL COLLAR BONE', 2614.0, 620.0, None],
#  ('saline', '23130'): ['REMOVE SHOULDER BONE PART', 5757.068, 775.0, None],
#  ('saline', '23150'): ['REMOVAL OF HUMERUS LESION', 9877.97, None, None],
#  ('saline', '23350'): ['INJECTION FOR SHOULDER X-RAY', 878.0, None, None],
#  ('saline', '23410'): ['REPAIR ROTATOR CUFF ACUTE', 13457.0, None, None],
#  ('saline', '23412'): ['REPAIR ROTATOR CUFF CHRONIC', 3105.0, 1725.0, None],
#  ('saline', '23430'): ['REPAIR BICEPS TENDON', 4644.475142, None, None],
#  ('saline', '23460'): ['REPAIR SHOULDER CAPSULE', 11163.0, None, None],
#  ('saline', '23462'): ['REPAIR SHOULDER CAPSULE', 14201.0, None, None],
#  ('saline', '23465'): ['REPAIR SHOULDER CAPSULE', 14694.75, None, None],
#  ('saline', '23466'): ['REPAIR SHOULDER CAPSULE', 5188.0, None, None],
#  ('saline', '23473'): ['REVIS RECONST SHOULDER JOINT', 8785.0, None, None],
#  ('saline', '23515'): ['TREAT CLAVICLE FRACTURE', 9829.864666, None, None],
#  ('saline', '23552'): ['TREAT CLAVICLE DISLOCATION', 18103.0, None, None],
#  ('saline', '23615'): ['TREAT HUMERUS FRACTURE', 12219.666666, None, None],
#  ('saline', '23650'): ['TREAT SHOULDER DISLOCATION', 1830.4775, None, None],
#  ('saline', '23670'): ['TREAT DISLOCATION/FRACTURE', 14210.353333, None, None],
#  ('saline', '23700'): ['FIXATION OF SHOULDER', 4041.9775, None, None],
#  ('saline', '24075'): ['EXC ARM/ELBOW LES SC < 3 CM', 5516.0, 772.0, None],
#  ('saline', '24105'): ['REMOVAL OF ELBOW BURSA', 5175.666666, None, None],
#  ('saline', '24147'): ['PARTIAL REMOVAL OF ELBOW', 3388.0, None, None],
#  ('saline', '24200'): ['REMOVAL OF ARM FOREIGN BODY', 6520.21, None, None],
#  ('saline', '24300'): ['MANIPULATE ELBOW W/ANESTH', 2705.0, None, None],
#  ('saline', '24341'): ['REPAIR ARM TENDON/MUSCLE', 5516.0, None, None],
#  ('saline', '24342'): ['REPAIR OF RUPTURED TENDON', 8000.122, None, None],
#  ('saline', '24344'): ['RECONSTRUCT ELBOW LAT LIGMNT', 10917.0, None, None],
#  ('saline', '24359'): ['REPAIR ELBOW DEB/ATTCH OPEN', 8498.0, None, None],
#  ('saline', '24515'): ['TREAT HUMERUS FRACTURE', 17113.52, None, None],
#  ('saline', '24516'): ['TREAT HUMERUS FRACTURE', 13307.0, None, None],
#  ('saline', '24545'): ['TREAT HUMERUS FRACTURE', 17848.0, None, None],
#  ('saline', '24575'): ['TREAT HUMERUS FRACTURE', 7432.0, None, None],
#  ('saline', '24579'): ['TREAT HUMERUS FRACTURE', 12153.0, None, None],
#  ('saline', '24586'): ['TREAT ELBOW FRACTURE', 13940.225, None, None],
#  ('saline', '24640'): ['TREAT ELBOW DISLOCATION', 1701.87, None, None],
#  ('saline', '24685'): ['TREAT ULNAR FRACTURE', 18090.446666, None, None],
#  ('saline', '25000'): ['INCISION OF TENDON SHEATH', 5100.91, 643.66, None],
#  ('saline', '25111'): ['REMOVE WRIST TENDON LESION', 4491.0, 887.0, None],
#  ('saline', '25246'): ['INJECTION FOR WRIST X-RAY', 215.7, None, None],
#  ('saline', '25260'): ['REPAIR FOREARM TENDON/MUSCLE', 2942.5, None, None],
#  ('saline', '25312'): ['TRANSPLANT FOREARM TENDON', 4126.0, None, None],
#  ('saline', '25447'): ['REPAIR WRIST JOINTS', 6939.0, None, None],
#  ('saline', '25505'): ['TREAT FRACTURE OF RADIUS', 14683.32, None, None],
#  ('saline', '25515'): ['TREAT FRACTURE OF RADIUS', 16116.87, None, None],
#  ('saline', '25545'): ['TREAT FRACTURE OF ULNA', 8293.0, None, None],
#  ('saline', '25565'): ['TREAT FRACTURE RADIUS & ULNA', 5518.77, None, None],
#  ('saline', '25606'): ['TREAT FX DISTAL RADIAL', 8163.17, None, None],
#  ('saline', '25607'): ['TREAT FX RAD EXTRA-ARTICUL', 9837.466153, None, None],
#  ('saline', '25608'): ['TREAT FX RAD INTRA-ARTICUL', 11839.665, 620.0, None],
#  ('saline', '25609'): ['TREAT FX RADIAL 3+ FRAG', 12469.295, None, None],
#  ('saline', '25628'): ['TREAT WRIST BONE FRACTURE', 9851.0, None, None],
#  ('saline', '25652'): ['TREAT FRACTURE ULNAR STYLOID', 8580.0, None, None],
#  ('saline', '26010'): ['DRAINAGE OF FINGER ABSCESS', 2964.666666, None, None],
#  ('saline', '26011'): ['DRAINAGE OF FINGER ABSCESS', 5349.0, None, None],
#  ('saline', '26040'): ['RELEASE PALM CONTRACTURE', 4411.5, None, None],
#  ('saline', '26045'): ['RELEASE PALM CONTRACTURE', 5557.0, None, None],
#  ('saline', '26055'): ['INCISE FINGER TENDON SHEATH', 3742.763636, None, None],
#  ('saline', '26075'): ['EXPLORE/TREAT FINGER JOINT', 3500.0, None, None],
#  ('saline', '26115'): ['EXC HAND LES SC < 1.5 CM', 5188.0, None, None],
#  ('saline', '26160'): ['REMOVE TENDON SHEATH LESION', 5024.0, None, None],
#  ('saline', '26236'): ['PARTIAL REMOVAL FINGER BONE', 2071.0, None, None],
#  ('saline', '26350'): ['REPAIR FINGER/HAND TENDON', 14070.87, None, None],
#  ('saline', '26412'): ['REPAIR/GRAFT HAND TENDON', 6459.0, None, None],
#  ('saline', '26426'): ['REPAIR FINGER/HAND TENDON', 8508.0, None, None],
#  ('saline', '26440'): ['RELEASE PALM/FINGER TENDON', 7473.0, None, None],
#  ('saline', '26540'): ['REPAIR HAND JOINT', 6590.356666, None, None],
#  ('saline', '26608'): ['TREAT METACARPAL FRACTURE', 8007.41, None, None],
#  ('saline', '26615'): ['TREAT METACARPAL FRACTURE', 11258.588333, None, None],
#  ('saline', '26641'): ['TREAT THUMB DISLOCATION', 1787.0, None, None],
#  ('saline', '26650'): ['TREAT THUMB FRACTURE', 8714.86, None, None],
#  ('saline', '26727'): ['TREAT FINGER FRACTURE EACH', 4573.0, None, None],
#  ('saline', '26735'): ['TREAT FINGER FRACTURE EACH', 4000.0, None, None],
#  ('saline', '26742'): ['TREAT FINGER FRACTURE EACH', 8291.2, None, None],
#  ('saline', '26746'): ['TREAT FINGER FRACTURE EACH', 3615.5, None, None],
#  ('saline', '26765'): ['TREAT FINGER FRACTURE EACH', 3490.5, None, None],
#  ('saline', '26770'): ['TREAT FINGER DISLOCATION', 1787.0, None, None],
#  ('saline', '26850'): ['FUSION OF KNUCKLE', 8047.0, None, None],
#  ('saline', '26951'): ['AMPUTATION OF FINGER/THUMB', 6090.0, None, None],
#  ('saline', '27062'): ['REMOVE FEMUR LESION/BURSA', 4989.75, None, None],
#  ('saline', '27093'): ['INJECTION FOR HIP X-RAY', 829.35, None, None],
#  ('saline', '27235'): ['TREAT THIGH FRACTURE', 4901.0, None, None],
#  ('saline', '27299'): ['PELVIS/HIP JOINT SURGERY', 7281.5, None, None],
#  ('saline', '27301'): ['DRAIN THIGH/KNEE LESION', 7801.0, None, None],
#  ('saline', '27305'): ['INCISE THIGH TENDON & FASCIA', 5232.5, None, None],
#  ('saline', '27310'): ['EXPLORATION OF KNEE JOINT', 4413.0, None, None],
#  ('saline', '27331'): ['EXPLORE/TREAT KNEE JOINT', 4023.5, None, None],
#  ('saline', '27340'): ['REMOVAL OF KNEECAP BURSA', 2594.0, None, None],
#  ('saline', '27385'): ['REPAIR OF THIGH MUSCLE', 8349.23, None, None],
#  ('saline', '27412'): ['AUTOCHONDROCYTE IMPLANT KNEE', 10312.0, None, None],
#  ('saline', '27415'): ['OSTEOCHONDRAL KNEE ALLOGRAFT', 10302.0, None, None],
#  ('saline', '27418'): ['REPAIR DEGENERATED KNEECAP', 8679.666666, None, None],
#  ('saline', '27422'): ['REVISION OF UNSTABLE KNEECAP', 13115.09, None, None],
#  ('saline', '27427'): ['RECONSTRUCTION KNEE', 21793.03, None, None],
#  ('saline', '27428'): ['RECONSTRUCTION KNEE', 17273.715, None, None],
#  ('saline', '27429'): ['RECONSTRUCTION KNEE', 6949.5, None, None],
#  ('saline', '27447'): ['TOTAL KNEE ARTHROPLASTY', 13428.0, None, None],
#  ('saline', '27486'): ['REVISE/REPLACE KNEE JOINT', 12493.0, None, None],
#  ('saline', '27524'): ['TREAT KNEECAP FRACTURE', 10163.25, None, None],
#  ('saline', '27536'): ['TREAT KNEE FRACTURE', 13598.0, None, None],
#  ('saline', '27566'): ['TREAT KNEECAP DISLOCATION', 12344.15, None, None],
#  ('saline', '27570'): ['FIXATION OF KNEE JOINT', 4985.74875, None, None],
#  ('saline', '27599'): ['LEG SURGERY PROCEDURE', 4412.0, None, None],
#  ('saline', '27600'): ['DECOMPRESSION OF LOWER LEG', 2694.13, None, None],
#  ('saline', '27602'): ['DECOMPRESSION OF LOWER LEG', 5270.0, None, None],
#  ('saline', '27610'): ['EXPLORE/TREAT ANKLE JOINT', 6213.0, None, None],
#  ('saline', '27620'): ['EXPLORE/TREAT ANKLE JOINT', 11186.82, None, None],
#  ('saline', '27635'): ['REMOVE LOWER LEG BONE LESION', 5625.25, None, None],
#  ('saline', '27650'): ['REPAIR ACHILLES TENDON', 6557.7, None, None],
#  ('saline', '27652'): ['REPAIR/GRAFT ACHILLES TENDON', 10424.0, None, None],
#  ('saline', '27675'): ['REPAIR LOWER LEG TENDONS', 6382.0, None, None],
#  ('saline', '27695'): ['REPAIR OF ANKLE LIGAMENT', 5200.0, None, None],
#  ('saline', '27696'): ['REPAIR OF ANKLE LIGAMENTS', 7176.305, None, None],
#  ('saline', '27698'): ['REPAIR OF ANKLE LIGAMENT', 5183.333333, 787.0, None],
#  ('saline', '27705'): ['INCISION OF TIBIA', 10580.0, None, None],
#  ('saline', '27726'): ['REPAIR FIBULA NONUNION', 8114.44, None, None],
#  ('saline', '27759'): ['TREATMENT OF TIBIA FRACTURE', 3434.5, None, None],
#  ('saline', '27766'): ['OPTX MEDIAL ANKLE FX', 8129.0, None, None],
#  ('saline', '27792'): ['TREATMENT OF ANKLE FRACTURE', 6899.0, None, None],
#  ('saline', '27814'): ['TREATMENT OF ANKLE FRACTURE', 11130.292, None, None],
#  ('saline', '27822'): ['TREATMENT OF ANKLE FRACTURE', 10261.0, None, None],
#  ('saline', '27829'): ['TREAT LOWER LEG JOINT', 7637.0, None, None],
#  ('saline', '27870'): ['FUSION OF ANKLE JOINT OPEN', 8529.0, None, None],
#  ('saline', '28005'): ['TREAT FOOT BONE LESION', 5147.0, None, None],
#  ('saline', '28008'): ['INCISION OF FOOT FASCIA', 4395.533333, None, None],
#  ('saline', '28090'): ['REMOVAL OF FOOT LESION', 5013.0, None, None],
#  ('saline', '28104'): ['REMOVAL OF FOOT LESION', 11772.91, None, None],
#  ('saline', '28119'): ['REMOVAL OF HEEL SPUR', 7104.0, None, None],
#  ('saline', '28120'): ['PART REMOVAL OF ANKLE/HEEL', 4843.5, None, None],
#  ('saline', '28190'): ['REMOVAL OF FOOT FOREIGN BODY', 2835.0, None, None],
#  ('saline', '28192'): ['REMOVAL OF FOOT FOREIGN BODY', 7350.0, None, None],
#  ('saline', '28193'): ['REMOVAL OF FOOT FOREIGN BODY', 10439.65, None, None],
#  ('saline', '28200'): ['REPAIR OF FOOT TENDON', 6289.0, None, None],
#  ('saline', '28238'): ['REVISION OF FOOT TENDON', 7680.0, None, None],
#  ('saline', '28285'): ['REPAIR OF HAMMERTOE', 4456.478571, None, None],
#  ('saline', '28296'): ['CORRECTION HALLUX VALGUS', 7104.0, None, None],
#  ('saline', '28299'): ['CORRECTION HALLUX VALGUS', 7760.0, None, None],
#  ('saline', '28308'): ['INCISION OF METATARSAL', 6694.0, None, None],
#  ('saline', '28322'): ['REPAIR OF METATARSALS', 9865.5, None, None],
#  ('saline', '28445'): ['TREAT ANKLE FRACTURE', 8252.0, None, None],
#  ('saline', '28485'): ['TREAT METATARSAL FRACTURE', 9407.926, None, None],
#  ('saline', '28750'): ['FUSION OF BIG TOE JOINT', 6623.0, None, None],
#  ('saline', '28805'): ['AMPUTATION THRU METATARSAL', 6459.0, None, None],
#  ('saline', '28820'): ['AMPUTATION OF TOE', 6220.31, None, None],
#  ('saline', '28825'): ['PARTIAL AMPUTATION OF TOE', 1999.5, None, None],
#  ('saline', '29105'): ['APPLY LONG ARM SPLINT', 376.0, None, None],
#  ('saline', '29125'): ['APPLY FOREARM SPLINT', 310.0, None, None],
#  ('saline', '29445'): ['APPLY RIGID LEG CAST', 658.0, None, None],
#  ('saline', '29505'): ['APPLICATION LONG LEG SPLINT', 376.0, None, None],
#  ('saline', '29515'): ['APPLICATION LOWER LEG SPLINT', 376.0, None, None],
#  ('saline', '29580'): ['APPLICATION OF PASTE BOOT', 341.830512, None, 358.0],
#  ('saline', '29806'): ['SHOULDER ARTHROSCOPY/SURGERY', 12721.0, None, None],
#  ('saline', '29807'): ['SHOULDER ARTHROSCOPY/SURGERY', 27427.08, None, None],
#  ('saline', '29822'): ['SHOULDER ARTHROSCOPY/SURGERY',
#   7051.714615,
#   None,
#   None],
#  ('saline', '29823'): ['SHOULDER ARTHROSCOPY/SURGERY',
#   5776.755769,
#   312.24,
#   None],
#  ('saline', '29824'): ['SHOULDER ARTHROSCOPY/SURGERY',
#   3084.269411,
#   None,
#   None],
#  ('saline', '29826'): ['SHOULDER ARTHROSCOPY/SURGERY', 3181.01, None, None],
#  ('saline', '29827'): ['ARTHROSCOP ROTATOR CUFF REPR',
#   9328.201666,
#   None,
#   None],
#  ('saline', '29828'): ['ARTHROSCOPY BICEPS TENODESIS', 22674.33, None, None],
#  ('saline', '29834'): ['ELBOW ARTHROSCOPY/SURGERY', 8785.0, None, None],
#  ('saline', '29846'): ['WRIST ARTHROSCOPY/SURGERY', 8756.026666, None, None],
#  ('saline', '29848'): ['WRIST ENDOSCOPY/SURGERY', 6981.0, None, None],
#  ('saline', '29855'): ['TIBIAL ARTHROSCOPY/SURGERY', 6330.5, None, None],
#  ('saline', '29856'): ['TIBIAL ARTHROSCOPY/SURGERY', 9000.0, None, None],
#  ('saline', '29861'): ['HIP ARTHRO W/FB REMOVAL', 4618.0, None, None],
#  ('saline', '29862'): ['HIP ARTHR0 W/DEBRIDEMENT', 5013.0, None, None],
#  ('saline', '29863'): ['HIP ARTHR0 W/SYNOVECTOMY', 4618.0, None, None],
#  ('saline', '29870'): ['KNEE ARTHROSCOPY DX', 3721.333333, None, None],
#  ('saline', '29871'): ['KNEE ARTHROSCOPY/DRAINAGE', 7268.0, None, None],
#  ('saline', '29873'): ['KNEE ARTHROSCOPY/SURGERY', 6887.945555, None, None],
#  ('saline', '29874'): ['KNEE ARTHROSCOPY/SURGERY', 8817.0, None, None],
#  ('saline', '29875'): ['KNEE ARTHROSCOPY/SURGERY', 7104.0, None, None],
#  ('saline', '29876'): ['KNEE ARTHROSCOPY/SURGERY', 9592.538, None, None],
#  ('saline', '29877'): ['KNEE ARTHROSCOPY/SURGERY', 6858.0, None, None],
#  ('saline', '29879'): ['KNEE ARTHROSCOPY/SURGERY', 6858.0, None, None],
#  ('saline', '29880'): ['KNEE ARTHROSCOPY/SURGERY', 7522.303157, None, None],
#  ('saline', '29881'): ['KNEE ARTHROSCOPY/SURGERY', 8694.0, 556.5, None],
#  ('saline', '29882'): ['KNEE ARTHROSCOPY/SURGERY', 9970.616666, 887.0, None],
#  ('saline', '29883'): ['KNEE ARTHROSCOPY/SURGERY', 5843.5, None, None],
#  ('saline', '29888'): ['KNEE ARTHROSCOPY/SURGERY', 11892.0, None, None],
#  ('saline', '29898'): ['ANKLE ARTHROSCOPY/SURGERY', 10095.12, None, None],
#  ('saline', '29914'): ['HIP ARTHRO W/FEMOROPLASTY', 10252.0, None, None],
#  ('saline', '29915'): ['HIP ARTHRO ACETABULOPLASTY', 9523.0, None, None],
#  ('saline', '29916'): ['HIP ARTHRO W/LABRAL REPAIR', 11564.0, None, None],
#  ('saline', '29999'): ['ARTHROSCOPY OF JOINT', 4909.5, None, None],
#  ('saline', '30130'): ['EXCISE INFERIOR TURBINATE', 3674.13, None, None],
#  ('saline', '30140'): ['RESECT INFERIOR TURBINATE', 2517.96875, None, None],
#  ('saline', '30300'): ['REMOVE NASAL FOREIGN BODY', 1070.0, None, None],
#  ('saline', '30310'): ['REMOVE NASAL FOREIGN BODY', 4578.31, None, None],
#  ('saline', '30320'): ['REMOVE NASAL FOREIGN BODY', 4245.0, None, None],
#  ('saline', '30520'): ['REPAIR OF NASAL SEPTUM', 4138.816, None, None],
#  ('saline', '31254'): ['NSL/SINS NDSC W/PRTL ETHMDCT', 3593.0, None, None],
#  ('saline', '31255'): ['NSL/SINS NDSC W/TOT ETHMDCT', 4045.03, None, None],
#  ('saline', '31256'): ['EXPLORATION MAXILLARY SINUS', 5512.065, None, None],
#  ('saline', '31500'): ['INSERT EMERGENCY AIRWAY', 1992.75, None, None],
#  ('saline', '31525'): ['DX LARYNGOSCOPY EXCL NB', 4962.76, None, None],
#  ('saline', '31536'): ['LARYNGOSCOPY W/BX & OP SCOPE', 6858.0, None, None],
#  ('saline', '31572'): ['LARGSC W/LASER DSTRJ LES', 9686.11, None, None],
#  ('saline', '31720'): ['CLEARANCE OF AIRWAYS', 536.0, None, None],
#  ('saline', '31820'): ['CLOSURE OF WINDPIPE LESION', 6377.0, None, None],
#  ('saline', '32405'): ['PERCUT BX LUNG/MEDIASTINUM', 3025.53, None, None],
#  ('saline', '32552'): ['REMOVE LUNG CATHETER', 1891.0, None, None],
#  ('saline', '32555'): ['ASPIRATE PLEURA W/ IMAGING', 2080.0, None, None],
#  ('saline', '33264'): ['RMVL & RPLCMT DFB GEN MLT LD', 69491.4, None, None],
#  ('saline', '36245'): ['INS CATH ABD/L-EXT ART 1ST', 2235.0, None, None],
#  ('saline', '36410'): ['NON-ROUTINE BL DRAW 3/> YRS', 5098.0, None, None],
#  ('saline', '36415'): ['ROUTINE VENIPUNCTURE', 14.0, None, None],
#  ('saline', '36430'): ['BLOOD TRANSFUSION SERVICE', 1070.0, 416.475, None],
#  ('saline', '36556'): ['INSERT NON-TUNNEL CV CATH', 3056.0, None, None],
#  ('saline', '36561'): ['INSERT TUNNELED CV CATH', 7473.0, None, None],
#  ('saline', '36565'): ['INSERT TUNNELED CV CATH', 13625.0, None, None],
#  ('saline', '36569'): ['INSJ PICC 5 YR+ W/O IMAGING', 3230.561875, None, None],
#  ('saline', '36571'): ['INSERT PICVAD CATH', 5352.0, None, None],
#  ('saline', '36573'): ['INSJ PICC RS&I 5 YR+', 3056.0, None, None],
#  ('saline', '36582'): ['REPLACE TUNNELED CV CATH', 5639.0, None, None],
#  ('saline', '36590'): ['REMOVAL TUNNELED CV CATH', 4737.0, None, None],
#  ('saline', '36591'): ['DRAW BLOOD OFF VENOUS DEVICE', 297.0, None, None],
#  ('saline', '36592'): ['COLLECT BLOOD FROM PICC', 297.0, None, None],
#  ('saline', '36593'): ['DECLOT VASCULAR DEVICE', 805.0, None, None],
#  ('saline', '36598'): ['INJ W/FLUOR EVAL CV DEVICE', 523.0, None, None],
#  ('saline', '36600'): ['WITHDRAWAL OF ARTERIAL BLOOD', 297.0, None, None],
#  ('saline', '36821'): ['AV FUSION DIRECT ANY SITE', 19414.08, None, None],
#  ('saline', '36830'): ['ARTERY-VEIN NONAUTOGRAFT', 21788.0, None, None],
#  ('saline', '37220'): ['ILIAC REVASC', 13069.0, None, None],
#  ('saline', '37221'): ['ILIAC REVASC W/STENT', 23590.0, None, None],
#  ('saline', '37224'): ['FEM/POPL REVAS W/TLA', 13069.0, None, None],
#  ('saline', '37225'): ['FEM/POPL REVAS W/ATHER', 20284.17, 1665.625, None],
#  ('saline', '37228'): ['TIB/PER REVASC W/TLA', 27011.0, None, None],
#  ('saline', '37609'): ['TEMPORAL ARTERY PROCEDURE', 7678.0, None, None],
#  ('saline', '38500'): ['BIOPSY/REMOVAL LYMPH NODES', 4873.666666, None, None],
#  ('saline', '38505'): ['NEEDLE BIOPSY LYMPH NODES', 3843.0, None, None],
#  ('saline', '41800'): ['DRAINAGE OF GUM LESION', 1432.0, None, None],
#  ('saline', '41899'): ['DENTAL SURGERY PROCEDURE', 6049.0, None, None],
#  ('saline', '42330'): ['REMOVAL OF SALIVARY STONE', 4491.0, None, None],
#  ('saline', '42700'): ['DRAINAGE OF TONSIL ABSCESS', 2611.42, None, None],
#  ('saline', '42820'): ['REMOVE TONSILS AND ADENOIDS', 4409.0, None, None],
#  ('saline', '42821'): ['REMOVE TONSILS AND ADENOIDS', 4204.0, None, None],
#  ('saline', '42826'): ['REMOVAL OF TONSILS', 4819.0, None, None],
#  ('saline', '42830'): ['REMOVAL OF ADENOIDS', 5212.82, None, None],
#  ('saline', '42831'): ['REMOVAL OF ADENOIDS', 3925.0, None, None],
#  ('saline', '43235'): ['EGD DIAGNOSTIC BRUSH WASH', 2352.81, 578.0, None],
#  ('saline', '43239'): ['EGD BIOPSY SINGLE/MULTIPLE', 2352.81, 581.14, None],
#  ('saline', '43245'): ['EGD DILATE STRICTURE', 3080.0, None, None],
#  ('saline', '43247'): ['EGD REMOVE FOREIGN BODY', 2591.382, None, None],
#  ('saline', '43248'): ['EGD GUIDE WIRE INSERTION', 4901.0, None, None],
#  ('saline', '43249'): ['ESOPH EGD DILATION <30 MM', 3032.5875, None, None],
#  ('saline', '43280'): ['LAPAROSCOPY FUNDOPLASTY', 12691.5, None, None],
#  ('saline', '43281'): ['LAP PARAESOPHAG HERN REPAIR', 24223.0, None, None],
#  ('saline', '43762'): ['RPLC GTUBE NO REVJ TRC', 2005.175, None, None],
#  ('saline', '43770'): ['LAP PLACE GASTR ADJ DEVICE', 15043.0, None, None],
#  ('saline', '43774'): ['LAP RMVL GASTR ADJ ALL PARTS',
#   10529.833333,
#   None,
#   None],
#  ('saline', '43886'): ['REVISE GASTRIC PORT OPEN', 9208.0, None, None],
#  ('saline', '43888'): ['CHANGE GASTRIC PORT OPEN', 7933.5, None, None],
#  ('saline', '43999'): ['STOMACH SURGERY PROCEDURE', 2102.0, None, None],
#  ('saline', '44180'): ['LAP ENTEROLYSIS', 9688.0, None, None],
#  ('saline', '44376'): ['SMALL BOWEL ENDOSCOPY', 2273.0, None, None],
#  ('saline', '44388'): ['COLONOSCOPY THRU STOMA SPX', 2273.0, None, None],
#  ('saline', '44970'): ['LAPAROSCOPY APPENDECTOMY', 10695.637419, None, None],
#  ('saline', '45172'): ['EXC RECT TUM TRANSANAL FULL', 7976.0, None, None],
#  ('saline', '45330'): ['DIAGNOSTIC SIGMOIDOSCOPY', 2273.0, None, None],
#  ('saline', '45331'): ['SIGMOIDOSCOPY AND BIOPSY', 1993.0, None, None],
#  ('saline', '45378'): ['DIAGNOSTIC COLONOSCOPY', 2336.67, 578.813333, 1655.0],
#  ('saline', '45380'): ['COLONOSCOPY AND BIOPSY', 2273.0, 544.9, None],
#  ('saline', '45385'): ['COLONOSCOPY W/LESION REMOVAL',
#   1884.579841,
#   628.59,
#   1672.0],
#  ('saline', '45560'): ['REPAIR OF RECTOCELE', 3296.0, None, None],
#  ('saline', '45915'): ['REMOVE RECTAL OBSTRUCTION', 4614.0, None, None],
#  ('saline', '46040'): ['INCISION OF RECTAL ABSCESS', 4655.0, None, None],
#  ('saline', '46050'): ['INCISION OF ANAL ABSCESS', 11041.02, None, None],
#  ('saline', '46200'): ['REMOVAL OF ANAL FISSURE', 6991.745, None, None],
#  ('saline', '46250'): ['REMOVE EXT HEM GROUPS 2+', 4044.0, None, None],
#  ('saline', '46255'): ['REMOVE INT/EXT HEM 1 GROUP', 7525.0, 905.0, None],
#  ('saline', '46257'): ['REMOVE IN/EX HEM GRP & FISS', 7145.0, None, None],
#  ('saline', '46258'): ['REMOVE IN/EX HEM GRP W/FISTU', 5844.0, None, None],
#  ('saline', '46260'): ['REMOVE IN/EX HEM GROUPS 2+', 7944.412857, None, None],
#  ('saline', '46270'): ['REMOVE ANAL FIST SUBQ', 5885.0, None, None],
#  ('saline', '46320'): ['REMOVAL OF HEMORRHOID CLOT', 7898.576666, None, None],
#  ('saline', '46910'): ['DESTRUCTION ANAL LESION(S)', 4778.0, None, None],
#  ('saline', '46999'): ['ANUS SURGERY PROCEDURE', 3937.5, None, None],
#  ('saline', '47000'): ['NEEDLE BIOPSY OF LIVER', 3843.0, None, None],
#  ('saline', '47562'): ['LAPAROSCOPIC CHOLECYSTECTOMY',
#   10440.695666,
#   1035.896666,
#   3181.0],
#  ('saline', '47563'): ['LAPARO CHOLECYSTECTOMY/GRAPH', 15485.31, None, None],
#  ('saline', '49083'): ['ABD PARACENTESIS W/IMAGING', 2695.0, None, None],
#  ('saline', '49185'): ['SCLEROTX FLUID COLLECTION', 1721.0, None, None],
#  ('saline', '49320'): ['DIAG LAPARO SEPARATE PROC', 5762.0, None, None],
#  ('saline', '49322'): ['LAPAROSCOPY ASPIRATION', 7836.89, None, None],
#  ('saline', '49324'): ['LAP INSERT TUNNEL IP CATH', 6049.0, None, None],
#  ('saline', '49329'): ['LAPARO PROC ABDM/PER/OMENT', 7606.0, None, None],
#  ('saline', '49407'): ['IMAGE CATH FLUID TRNS/VGNL', 2463.42, None, None],
#  ('saline', '49505'): ['PRP I/HERN INIT REDUC >5 YR', 10313.0, None, None],
#  ('saline', '49507'): ['PRP I/HERN INIT BLOCK >5 YR', 11136.165, None, None],
#  ('saline', '49520'): ['REREPAIR ING HERNIA REDUCE', 8466.666666, None, None],
#  ('saline', '49566'): ['REREPAIR VENTRL HERN BLOCK', 25081.79, None, None],
#  ('saline', '49585'): ['RPR UMBIL HERN REDUC > 5 YR', 6998.0, None, None],
#  ('saline', '49587'): ['RPR UMBIL HERN BLOCK > 5 YR', 8358.0, None, None],
#  ('saline', '49650'): ['LAP ING HERNIA REPAIR INIT', 11388.0, None, None],
#  ('saline', '49651'): ['LAP ING HERNIA REPAIR RECUR', 10283.0, None, None],
#  ('saline', '49652'): ['LAP VENT/ABD HERNIA REPAIR', 16590.215, None, None],
#  ('saline', '49653'): ['LAP VENT/ABD HERN PROC COMP',
#   13335.001666,
#   None,
#   None],
#  ('saline', '49654'): ['LAP INC HERNIA REPAIR', 11248.0225, None, None],
#  ('saline', '49655'): ['LAP INC HERN REPAIR COMP', 12872.038888, None, None],
#  ('saline', '49656'): ['LAP INC HERNIA REPAIR RECUR',
#   11624.666666,
#   None,
#   None],
#  ('saline', '50080'): ['REMOVAL OF KIDNEY STONE', 11101.5, 1092.0, None],
#  ('saline', '50200'): ['RENAL BIOPSY PERQ', 3996.0, None, None],
#  ('saline', '50389'): ['REMOVE RENAL TUBE W/FLUORO', 1571.0, None, None],
#  ('saline', '50432'): ['PLMT NEPHROSTOMY CATHETER', 4860.0, 193.0, None],
#  ('saline', '50590'): ['FRAGMENTING OF KIDNEY STONE', 4996.3525, None, None],
#  ('saline', '50688'): ['CHANGE OF URETER TUBE/STENT', 4860.0, None, None],
#  ('saline', '50694'): ['PLMT URETERAL STENT PRQ', 8517.0, None, None],
#  ('saline', '50695'): ['PLMT URETERAL STENT PRQ', 6355.0, None, None],
#  ('saline', '50727'): ['REVISE URETER', 4900.0, None, None],
#  ('saline', '51600'): ['INJECTION FOR BLADDER X-RAY', 1481.5, None, None],
#  ('saline', '51700'): ['IRRIGATION OF BLADDER', 2286.5, None, None],
#  ('saline', '51701'): ['INSERT BLADDER CATHETER', 297.0, None, None],
#  ('saline', '51702'): ['INSERT TEMP BLADDER CATH', 297.0, None, None],
#  ('saline', '51798'): ['US URINE CAPACITY MEASURE', 156.0, None, None],
#  ('saline', '52000'): ['CYSTOSCOPY', 2656.2525, None, None],
#  ('saline', '52001'): ['CYSTOSCOPY REMOVAL OF CLOTS', 6986.5, None, None],
#  ('saline', '52005'): ['CYSTOSCOPY & URETER CATHETER', 7984.745, None, None],
#  ('saline', '52204'): ['CYSTOSCOPY W/BIOPSY(S)', 5821.5, None, None],
#  ('saline', '52234'): ['CYSTOSCOPY AND TREATMENT', 7842.0, None, None],
#  ('saline', '52235'): ['CYSTOSCOPY AND TREATMENT', 5212.0, None, None],
#  ('saline', '52240'): ['CYSTOSCOPY AND TREATMENT', 6986.5, None, None],
#  ('saline', '52260'): ['CYSTOSCOPY AND TREATMENT', 3145.357142, None, None],
#  ('saline', '52276'): ['CYSTOSCOPY AND TREATMENT', 5352.0, None, None],
#  ('saline', '52287'): ['CYSTOSCOPY CHEMODENERVATION', 6202.0, None, None],
#  ('saline', '52310'): ['CYSTOSCOPY AND TREATMENT', 5899.57, None, None],
#  ('saline', '52317'): ['REMOVE BLADDER STONE', 2255.0, None, None],
#  ('saline', '52325'): ['CYSTOSCOPY STONE REMOVAL', 2091.0, None, None],
#  ('saline', '52330'): ['CYSTOSCOPY AND TREATMENT', 6914.0, None, None],
#  ('saline', '52332'): ['CYSTOSCOPY AND TREATMENT', 6407.0, None, None],
#  ('saline', '52351'): ['CYSTOURETERO & OR PYELOSCOPE', 3757.0, None, None],
#  ('saline', '52352'): ['CYSTOURETERO W/STONE REMOVE', 3392.2, None, None],
#  ('saline', '52356'): ['CYSTO/URETERO W/LITHOTRIPSY', 8565.8, None, None],
#  ('saline', '52441'): ['CYSTOURETHRO W/IMPLANT', 3343.0, None, None],
#  ('saline', '52442'): ['CYSTOURETHRO W/ADDL IMPLANT', 1271.0, None, None],
#  ('saline', '53500'): ['URETHRLYS TRANSVAG W/ SCOPE', 8753.0, None, None],
#  ('saline', '54150'): ['CIRCUMCISION W/REGIONL BLOCK', 4860.0, None, None],
#  ('saline', '54161'): ['CIRCUM 28 DAYS OR OLDER', 7977.09, None, None],
#  ('saline', '54600'): ['REDUCE TESTIS TORSION', 7760.12, None, None],
#  ('saline', '55040'): ['REMOVAL OF HYDROCELE', 5639.0, None, None],
#  ('saline', '55250'): ['REMOVAL OF SPERM DUCT(S)', 4983.0, None, None],
#  ('saline', '55520'): ['REMOVAL OF SPERM CORD LESION', 5326.5, None, None],
#  ('saline', '55700'): ['BIOPSY OF PROSTATE', 5626.071428, 241.69, None],
#  ('saline', '56405'): ['I & D OF VULVA/PERINEUM', 5147.0, None, None],
#  ('saline', '57000'): ['EXPLORATION OF VAGINA', 5499.74, None, None],
#  ('saline', '57023'): ['I & D VAG HEMATOMA NON-OB', 7268.28, None, 1274.0],
#  ('saline', '57061'): ['DESTROY VAG LESIONS SIMPLE', 6371.56, None, None],
#  ('saline', '57065'): ['DESTROY VAG LESIONS COMPLEX', 4884.0, None, None],
#  ('saline', '57135'): ['REMOVE VAGINA LESION', 8696.91, None, None],
#  ('saline', '57200'): ['REPAIR OF VAGINA', 6658.0, None, None],
#  ('saline', '57240'): ['ANTERIOR COLPORRHAPHY', 5963.5, None, None],
#  ('saline', '57250'): ['REPAIR RECTUM & VAGINA', 4831.0, None, None],
#  ('saline', '57260'): ['CMBN ANT PST COLPRHY', 7536.5, None, None],
#  ('saline', '57288'): ['REPAIR BLADDER DEFECT', 9112.734615, None, None],
#  ('saline', '57410'): ['PELVIC EXAMINATION', 4000.0, None, None],
#  ('saline', '57520'): ['CONIZATION OF CERVIX', 7235.295, None, None],
#  ('saline', '57522'): ['CONIZATION OF CERVIX', 4573.0, None, None],
#  ('saline', '58120'): ['DILATION AND CURETTAGE', 5946.94875, None, None],
#  ('saline', '58145'): ['MYOMECTOMY VAG METHOD', 5188.0, None, None],
#  ('saline', '58260'): ['VAGINAL HYSTERECTOMY', 10568.0, None, None],
#  ('saline', '58262'): ['VAG HYST INCLUDING T/O', 9208.0, 1240.0, 2709.0],
#  ('saline', '58291'): ['VAG HYST INCL T/O COMPLEX', 12918.0, None, None],
#  ('saline', '58300'): ['INSERT INTRAUTERINE DEVICE', 2823.61, None, None],
#  ('saline', '58301'): ['REMOVE INTRAUTERINE DEVICE', 3372.0, None, None],
#  ('saline', '58353'): ['ENDOMETR ABLATE THERMAL', 4267.346666, None, None],
#  ('saline', '58541'): ['LSH UTERUS 250 G OR LESS', 9441.0, None, None],
#  ('saline', '58544'): ['LSH W/T/O UTERUS ABOVE 250 G', 12475.0, None, None],
#  ('saline', '58552'): ['LAPARO-VAG HYST INCL T/O', 13295.0, None, None],
#  ('saline', '58554'): ['LAPARO-VAG HYST W/T/O COMPL', 10425.0, None, None],
#  ('saline', '58558'): ['HYSTEROSCOPY BIOPSY', 6506.152, None, None],
#  ('saline', '58560'): ['HYSTEROSCOPY RESECT SEPTUM', 6450.0, None, None],
#  ('saline', '58562'): ['HYSTEROSCOPY REMOVE FB', 2163.5, None, None],
#  ('saline', '58563'): ['HYSTEROSCOPY ABLATION', 7129.793571, None, None],
#  ('saline', '58571'): ['TLH W/T/O 250 G OR LESS', 14023.0, None, None],
#  ('saline', '58573'): ['TLH W/T/O UTERUS OVER 250 G', 17253.0, None, None],
#  ('saline', '58578'): ['LAPARO PROC UTERUS', 8293.0, None, None],
#  ('saline', '58661'): ['LAPAROSCOPY REMOVE ADNEXA', 7268.0, 959.5, None],
#  ('saline', '58662'): ['LAPAROSCOPY EXCISE LESIONS', 9210.0975, None, None],
#  ('saline', '58670'): ['LAPAROSCOPY TUBAL CAUTERY', 6570.954285, None, None],
#  ('saline', '58700'): ['REMOVAL OF FALLOPIAN TUBE', 8621.0, None, None],
#  ('saline', '58999'): ['GENITAL SURGERY PROCEDURE', 2350.0, None, None],
#  ('saline', '59025'): ['FETAL NON-STRESS TEST', 463.0, None, None],
#  ('saline', '59151'): ['TREAT ECTOPIC PREGNANCY', 11606.246666, None, None],
#  ('saline', '59412'): ['ANTEPARTUM MANIPULATION', 7065.446666, None, None],
#  ('saline', '59812'): ['TREATMENT OF MISCARRIAGE', 6043.244, None, None],
#  ('saline', '59820'): ['CARE OF MISCARRIAGE', 4949.509, None, None],
#  ('saline', '59821'): ['TREATMENT OF MISCARRIAGE', 7291.49, None, None],
#  ('saline', '60100'): ['BIOPSY OF THYROID', 1618.0, None, None],
#  ('saline', '60280'): ['REMOVE THYROID DUCT LESION', 8613.0, None, None],
#  ('saline', '62270'): ['DX LMBR SPI PNXR', 1446.275, None, None],
#  ('saline', '62273'): ['INJECT EPIDURAL PATCH', 1673.0, None, None],
#  ('saline', '62304'): ['MYELOGRAPHY LUMBAR INJECTION', 1932.0, None, None],
#  ('saline', '62323'): ['NJX INTERLAMINAR LMBR/SAC', 1673.0, None, None],
#  ('saline', '62328'): ['DX LMBR SPI PNXR W/FLUOR/CT', 1749.0, None, None],
#  ('saline', '64415'): ['NJX AA&/STRD BRACH PLEXUS', 863.02, 194.666666, None],
#  ('saline', '64447'): ['NJX AA&/STRD FEMORAL NERVE', 702.0, None, None],
#  ('saline', '64581'): ['IMPLANT NEUROELECTRODES', 7238.0, None, None],
#  ('saline', '64590'): ['INSRT/REDO PN/GASTR STIMUL', 2424.34, None, None],
#  ('saline', '64718'): ['REVISE ULNAR NERVE AT ELBOW', 4023.604705, None, None],
#  ('saline', '64721'): ['CARPAL TUNNEL SURGERY', 4860.0, None, None],
#  ('saline', '65205'): ['REMOVE FOREIGN BODY FROM EYE', 1663.0, None, None],
#  ('saline', '69005'): ['DRAIN EXTERNAL EAR LESION', 5188.0, None, None],
#  ('saline', '69200'): ['CLEAR OUTER EAR CANAL', 1070.0, None, None],
#  ('saline', '69205'): ['CLEAR OUTER EAR CANAL', 4211.04, None, None],
#  ('saline', '69210'): ['REMOVE IMPACTED EAR WAX UNI', 1917.5, None, None],
#  ('saline', '69424'): ['REMOVE VENTILATING TUBE', 4040.0, None, None],
#  ('saline', '69436'): ['CREATE EARDRUM OPENING', 2996.01, None, None],
#  ('saline', '70110'): ['X-RAY EXAM OF JAW 4/> VIEWS', 333.0, None, None],
#  ('saline', '70150'): ['X-RAY EXAM OF FACIAL BONES', 314.0, None, None],
#  ('saline', '70160'): ['X-RAY EXAM OF NASAL BONES', 282.0, None, None],
#  ('saline', '70210'): ['X-RAY EXAM OF SINUSES', 263.0, None, None],
#  ('saline', '70220'): ['X-RAY EXAM OF SINUSES', 404.0, None, None],
#  ('saline', '70250'): ['X-RAY EXAM OF SKULL', 314.0, None, None],
#  ('saline', '70260'): ['X-RAY EXAM OF SKULL', 314.0, None, None],
#  ('saline', '70360'): ['X-RAY EXAM OF NECK', 224.0, None, None],
#  ('saline', '70450'): ['CT HEAD/BRAIN W/O DYE', 1479.0, None, None],
#  ('saline', '70460'): ['CT HEAD/BRAIN W/DYE', 1706.0, None, None],
#  ('saline', '70470'): ['CT HEAD/BRAIN W/O & W/DYE', 2092.0, None, None],
#  ('saline', '70480'): ['CT ORBIT/EAR/FOSSA W/O DYE', 1724.0, None, None],
#  ('saline', '70481'): ['CT ORBIT/EAR/FOSSA W/DYE', 1760.5, None, None],
#  ('saline', '70486'): ['CT MAXILLOFACIAL W/O DYE', 1740.0, None, None],
#  ('saline', '70487'): ['CT MAXILLOFACIAL W/DYE', 1511.0, None, None],
#  ('saline', '70490'): ['CT SOFT TISSUE NECK W/O DYE', 1415.0, None, None],
#  ('saline', '70491'): ['CT SOFT TISSUE NECK W/DYE', 1713.0, 787.0, None],
#  ('saline', '70496'): ['CT ANGIOGRAPHY HEAD', 1982.0, None, None],
#  ('saline', '70498'): ['CT ANGIOGRAPHY NECK', 1992.0, None, None],
#  ('saline', '70540'): ['MRI ORBIT/FACE/NECK W/O DYE', 2209.0, None, None],
#  ('saline', '70543'): ['MRI ORBT/FAC/NCK W/O &W/DYE', 3048.0, None, None],
#  ('saline', '70544'): ['MR ANGIOGRAPHY HEAD W/O DYE', 3100.0, None, None],
#  ('saline', '70551'): ['MRI BRAIN STEM W/O DYE', 2745.0, 1069.0, None],
#  ('saline', '70553'): ['MRI BRAIN STEM W/O & W/DYE', 4484.0, 1069.0, 3399.0],
#  ('saline', '71045'): ['X-RAY EXAM CHEST 1 VIEW', 174.0, None, None],
#  ('saline', '71046'): ['X-RAY EXAM CHEST 2 VIEWS', 174.0, 89.074, 41.36],
#  ('saline', '71047'): ['X-RAY EXAM CHEST 3 VIEWS', 174.0, None, None],
#  ('saline', '71100'): ['X-RAY EXAM RIBS UNI 2 VIEWS', 174.0, None, None],
#  ('saline', '71101'): ['X-RAY EXAM UNILAT RIBS/CHEST', 352.0, None, None],
#  ('saline', '71111'): ['X-RAY EXAM RIBS/CHEST4/> VWS', 331.0, None, None],
#  ('saline', '71120'): ['X-RAY EXAM BREASTBONE 2/>VWS', 240.0, None, None],
#  ('saline', '71250'): ['CT THORAX W/O DYE', 1582.0, 436.2, None],
#  ('saline', '71260'): ['CT THORAX W/DYE', 1813.0, 787.0, None],
#  ('saline', '71275'): ['CT ANGIOGRAPHY CHEST', 2279.0, 163.23, None],
#  ('saline', '72020'): ['X-RAY EXAM OF SPINE 1 VIEW', 249.0, None, None],
#  ('saline', '72040'): ['X-RAY EXAM NECK SPINE 2-3 VW', 315.0, None, None],
#  ('saline', '72050'): ['X-RAY EXAM NECK SPINE 4/5VWS', 393.0, 294.75, None],
#  ('saline', '72052'): ['X-RAY EXAM NECK SPINE 6/>VWS', 709.0, None, None],
#  ('saline', '72072'): ['X-RAY EXAM THORAC SPINE 3VWS', 314.0, None, None],
#  ('saline', '72080'): ['X-RAY EXAM THORACOLMB 2/> VW', 273.0, None, None],
#  ('saline', '72082'): ['X-RAY EXAM ENTIRE SPI 2/3 VW', 314.0, None, None],
#  ('saline', '72100'): ['X-RAY EXAM L-S SPINE 2/3 VWS', 318.0, None, None],
#  ('saline', '72110'): ['X-RAY EXAM L-2 SPINE 4/>VWS', 386.0, None, None],
#  ('saline', '72114'): ['X-RAY EXAM L-S SPINE BENDING', 709.0, None, None],
#  ('saline', '72125'): ['CT NECK SPINE W/O DYE', 2099.0, None, None],
#  ('saline', '72128'): ['CT CHEST SPINE W/O DYE', 1457.0, None, None],
#  ('saline', '72129'): ['CT CHEST SPINE W/DYE', 1910.0, None, None],
#  ('saline', '72131'): ['CT LUMBAR SPINE W/O DYE', 1698.0, None, None],
#  ('saline', '72132'): ['CT LUMBAR SPINE W/DYE', 2099.0, None, None],
#  ('saline', '72141'): ['MRI NECK SPINE W/O DYE', 3079.0, 1048.0, 1121.0],
#  ('saline', '72146'): ['MRI CHEST SPINE W/O DYE', 2769.0, None, None],
#  ('saline', '72148'): ['MRI LUMBAR SPINE W/O DYE', 3205.0, 838.1875, None],
#  ('saline', '72156'): ['MRI NECK SPINE W/O & W/DYE', 4334.0, None, None],
#  ('saline', '72157'): ['MRI CHEST SPINE W/O & W/DYE', 3940.0, None, None],
#  ('saline', '72158'): ['MRI LUMBAR SPINE W/O & W/DYE', 4423.0, None, None],
#  ('saline', '72170'): ['X-RAY EXAM OF PELVIS', 314.0, None, None],
#  ('saline', '72191'): ['CT ANGIOGRAPH PELV W/O&W/DYE', 2193.0, None, None],
#  ('saline', '72192'): ['CT PELVIS W/O DYE', 1665.0, None, None],
#  ('saline', '72193'): ['CT PELVIS W/DYE', 1707.0, None, None],
#  ('saline', '72194'): ['CT PELVIS W/O & W/DYE', 2299.0, None, None],
#  ('saline', '72195'): ['MRI PELVIS W/O DYE', 2786.0, None, None],
#  ('saline', '72197'): ['MRI PELVIS W/O & W/DYE', 3179.0, 1048.0, None],
#  ('saline', '72202'): ['X-RAY EXAM SI JOINTS 3/> VWS', 314.0, None, None],
#  ('saline', '72220'): ['X-RAY EXAM SACRUM TAILBONE', 247.0, None, None],
#  ('saline', '73000'): ['X-RAY EXAM OF COLLAR BONE', 225.0, None, None],
#  ('saline', '73010'): ['X-RAY EXAM OF SHOULDER BLADE', 244.29, None, None],
#  ('saline', '73020'): ['X-RAY EXAM OF SHOULDER', 207.0, None, None],
#  ('saline', '73030'): ['X-RAY EXAM OF SHOULDER', 245.0, 183.75, None],
#  ('saline', '73040'): ['CONTRAST X-RAY OF SHOULDER', 663.0, None, None],
#  ('saline', '73060'): ['X-RAY EXAM OF HUMERUS', 282.0, None, None],
#  ('saline', '73070'): ['X-RAY EXAM OF ELBOW', 247.0, None, None],
#  ('saline', '73080'): ['X-RAY EXAM OF ELBOW', 254.0, None, None],
#  ('saline', '73090'): ['X-RAY EXAM OF FOREARM', 225.0, None, None],
#  ('saline', '73100'): ['X-RAY EXAM OF WRIST', 215.0, None, None],
#  ('saline', '73110'): ['X-RAY EXAM OF WRIST', 249.0, None, None],
#  ('saline', '73120'): ['X-RAY EXAM OF HAND', 366.285714, None, None],
#  ('saline', '73130'): ['X-RAY EXAM OF HAND', 229.0, None, None],
#  ('saline', '73140'): ['X-RAY EXAM OF FINGER(S)', 225.0, None, 120.52],
#  ('saline', '73200'): ['CT UPPER EXTREMITY W/O DYE', 1424.0, None, None],
#  ('saline', '73201'): ['CT UPPER EXTREMITY W/DYE', 1412.0, None, None],
#  ('saline', '73218'): ['MRI UPPER EXTREMITY W/O DYE', 2504.0, None, None],
#  ('saline', '73221'): ['MRI JOINT UPR EXTREM W/O DYE', 2456.0, 1069.0, None],
#  ('saline', '73222'): ['MRI JOINT UPR EXTREM W/DYE', 2753.75, None, None],
#  ('saline', '73223'): ['MRI JOINT UPR EXTR W/O&W/DYE', 3858.0, None, None],
#  ('saline', '73501'): ['X-RAY EXAM HIP UNI 1 VIEW', 174.0, None, None],
#  ('saline', '73502'): ['X-RAY EXAM HIP UNI 2-3 VIEWS', 174.0, None, None],
#  ('saline', '73522'): ['X-RAY EXAM HIPS BI 3-4 VIEWS', 314.0, None, None],
#  ('saline', '73525'): ['CONTRAST X-RAY OF HIP', 1078.0, None, None],
#  ('saline', '73552'): ['X-RAY EXAM OF FEMUR 2/>', 183.18, None, None],
#  ('saline', '73560'): ['X-RAY EXAM OF KNEE 1 OR 2', 280.620253, None, None],
#  ('saline', '73562'): ['X-RAY EXAM OF KNEE 3', 334.0, None, None],
#  ('saline', '73564'): ['X-RAY EXAM KNEE 4 OR MORE', 366.0, None, None],
#  ('saline', '73590'): ['X-RAY EXAM OF LOWER LEG', 300.0, None, None],
#  ('saline', '73600'): ['X-RAY EXAM OF ANKLE', 251.0, None, None],
#  ('saline', '73610'): ['X-RAY EXAM OF ANKLE', 311.0, 233.25, None],
#  ('saline', '73620'): ['X-RAY EXAM OF FOOT', 174.0, None, None],
#  ('saline', '73630'): ['X-RAY EXAM OF FOOT', 311.0, 66.49, None],
#  ('saline', '73650'): ['X-RAY EXAM OF HEEL', 247.0, None, None],
#  ('saline', '73660'): ['X-RAY EXAM OF TOE(S)', 225.0, None, None],
#  ('saline', '73700'): ['CT LOWER EXTREMITY W/O DYE', 1455.0, None, None],
#  ('saline', '73701'): ['CT LOWER EXTREMITY W/DYE', 1576.0, None, None],
#  ('saline', '73702'): ['CT LWR EXTREMITY W/O&W/DYE', 1920.2, None, None],
#  ('saline', '73706'): ['CT ANGIO LWR EXTR W/O&W/DYE', 3050.0, None, None],
#  ('saline', '73718'): ['MRI LOWER EXTREMITY W/O DYE', 2430.0, None, None],
#  ('saline', '73720'): ['MRI LWR EXTREMITY W/O&W/DYE', 3020.0, 1048.0, None],
#  ('saline', '73721'): ['MRI JNT OF LWR EXTRE W/O DYE', 2430.0, 1048.0, None],
#  ('saline', '73722'): ['MRI JOINT OF LWR EXTR W/DYE', 2666.0, None, None],
#  ('saline', '73723'): ['MRI JOINT LWR EXTR W/O&W/DYE', 3020.0, None, None],
#  ('saline', '74018'): ['X-RAY EXAM ABDOMEN 1 VIEW', 174.0, 127.02, None],
#  ('saline', '74019'): ['X-RAY EXAM ABDOMEN 2 VIEWS', 314.0, None, None],
#  ('saline', '74022'): ['X-RAY EXAM COMPLETE ABDOMEN', 450.0, None, None],
#  ('saline', '74150'): ['CT ABDOMEN W/O DYE', 2050.0, None, None],
#  ('saline', '74160'): ['CT ABDOMEN W/DYE', 2359.0, None, None],
#  ('saline', '74170'): ['CT ABDOMEN W/O & W/DYE', 2913.0, None, None],
#  ('saline', '74174'): ['CT ANGIO ABD&PELV W/O&W/DYE', 1398.0, None, None],
#  ('saline', '74175'): ['CT ANGIO ABDOM W/O & W/DYE', 2207.0, None, None],
#  ('saline', '74176'): ['CT ABD & PELVIS W/O CONTRAST', 3715.0, 787.0, None],
#  ('saline', '74177'): ['CT ABD & PELV W/CONTRAST', 4066.0, 664.5125, None],
#  ('saline', '74178'): ['CT ABD & PELV 1/> REGNS', 5212.0, 787.0, None],
#  ('saline', '74181'): ['MRI ABDOMEN W/O DYE', 3687.0, 1069.0, None],
#  ('saline', '74183'): ['MRI ABDOMEN W/O & W/DYE', 2918.0, None, None],
#  ('saline', '74220'): ['X-RAY XM ESOPHAGUS 1CNTRST', 564.0, None, None],
#  ('saline', '74221'): ['X-RAY XM ESOPHAGUS 2CNTRST', 509.0, 371.57, None],
#  ('saline', '74230'): ['X-RAY XM SWLNG FUNCJ C+', 318.0, None, None],
#  ('saline', '74240'): ['X-RAY XM UPR GI TRC 1CNTRST', 509.0, None, None],
#  ('saline', '74246'): ['X-RAY XM UPR GI TRC 2CNTRST', 509.0, 381.75, None],
#  ('saline', '74248'): ['X-RAY SM INT F-THRU STD', 105.0, None, None],
#  ('saline', '74250'): ['X-RAY XM SM INT 1CNTRST STD', 687.0, None, None],
#  ('saline', '74280'): ['X-RAY XM COLON 2CNTRST STD', 801.0, None, None],
#  ('saline', '74300'): ['X-RAY BILE DUCTS/PANCREAS', 712.0, None, None],
#  ('saline', '74420'): ['CONTRST X-RAY URINARY TRACT', 1078.0, None, None],
#  ('saline', '74430'): ['CONTRAST X-RAY BLADDER', 1078.0, None, None],
#  ('saline', '74740'): ['X-RAY FEMALE GENITAL TRACT', 732.0, None, None],
#  ('saline', '75635'): ['CT ANGIO ABDOMINAL ARTERIES', 2901.5, None, None],
#  ('saline', '75989'): ['ABSCESS DRAINAGE UNDER X-RAY', 836.0, None, None],
#  ('saline', '76000'): ['FLUOROSCOPY <1 HR PHYS/QHP', 644.0, None, None],
#  ('saline', '76010'): ['X-RAY NOSE TO RECTUM', 175.0, None, None],
#  ('saline', '76080'): ['X-RAY EXAM OF FISTULA', 1390.0, None, None],
#  ('saline', '76536'): ['US EXAM OF HEAD AND NECK', 495.0, 361.35, None],
#  ('saline', '76604'): ['US EXAM CHEST', 483.0, None, None],
#  ('saline', '76641'): ['ULTRASOUND BREAST COMPLETE', 217.0, None, None],
#  ('saline', '76642'): ['ULTRASOUND BREAST LIMITED', 217.0, 158.41, 121.02],
#  ('saline', '76700'): ['US EXAM ABDOM COMPLETE', 906.0, 661.38, 273.05],
#  ('saline', '76705'): ['ECHO EXAM OF ABDOMEN', 725.0, 543.75, None],
#  ('saline', '76706'): ['US ABDL AORTA SCREEN AAA', 314.0, None, None],
#  ('saline', '76770'): ['US EXAM ABDO BACK WALL COMP', 677.0, 494.21, None],
#  ('saline', '76800'): ['US EXAM SPINAL CANAL', 473.0, None, None],
#  ('saline', '76801'): ['OB US < 14 WKS SINGLE FETUS', 342.0, None, None],
#  ('saline', '76805'): ['OB US >= 14 WKS SNGL FETUS', 483.0, 344.78, 273.05],
#  ('saline', '76810'): ['OB US >= 14 WKS ADDL FETUS', 316.0, None, None],
#  ('saline', '76811'): ['OB US DETAILED SNGL FETUS', 644.0, None, None],
#  ('saline', '76815'): ['OB US LIMITED FETUS(S)', 473.0, 354.75, None],
#  ('saline', '76816'): ['OB US FOLLOW-UP PER FETUS', 323.0, None, None],
#  ('saline', '76817'): ['TRANSVAGINAL US OBSTETRIC', 694.0, None, None],
#  ('saline', '76819'): ['FETAL BIOPHYS PROFIL W/O NST', 625.0, None, None],
#  ('saline', '76830'): ['TRANSVAGINAL US NON-OB', 694.0, 506.62, None],
#  ('saline', '76856'): ['US EXAM PELVIC COMPLETE', 616.0, None, None],
#  ('saline', '76857'): ['US EXAM PELVIC LIMITED', 446.0, None, 178.47],
#  ('saline', '76870'): ['US EXAM SCROTUM', 706.0, None, 273.05],
#  ('saline', '76872'): ['US TRANSRECTAL', 314.0, None, None],
#  ('saline', '76881'): ['US COMPL JOINT R-T W/IMG', 431.0, None, None],
#  ('saline', '76882'): ['US LMTD JT/NONVASC XTR STRUX', 314.0, 224.25, None],
#  ('saline', '76942'): ['ECHO GUIDE FOR BIOPSY', 619.0, None, None],
#  ('saline', '77012'): ['CT SCAN FOR NEEDLE BIOPSY', 1965.85, None, None],
#  ('saline', '77063'): ['BREAST TOMOSYNTHESIS BI', 68.0, 49.64, None],
#  ('saline', '77065'): ['DX MAMMO INCL CAD UNI', 219.74, None, 183.72],
#  ('saline', '77066'): ['DX MAMMO INCL CAD BI', 280.72, 204.93, None],
#  ('saline', '77067'): ['SCR MAMMO BI INCL CAD', 232.1, 169.43, 188.86],
#  ('saline', '77074'): ['X-RAYS BONE SURVEY LIMITED', 470.0, None, None],
#  ('saline', '77080'): ['DXA BONE DENSITY AXIAL', 380.36, None, None],
# ...
#  ('saline', '83002'): ['ASSAY OF GONADOTROPIN (LH)', 94.0, None, None],
#  ('saline', '83003'): ['ASSAY GROWTH HORMONE (HGH)', 71.0, None, None],
#  ('saline', '83010'): ['ASSAY OF HAPTOGLOBIN QUANT', 73.0, None, None],
#  ('saline', '83021'): ['HEMOGLOBIN CHROMOTOGRAPHY', 79.0, None, None],
#  ('saline', '83036'): ['GLYCOSYLATED HEMOGLOBIN TEST', 53.0, 38.69, None],
#  ('saline', '83090'): ['ASSAY OF HOMOCYSTINE', 202.0, None, None],
#  ('saline', '83497'): ['ASSAY OF 5-HIAA', 77.0, None, None],
#  ('saline', '83498'): ['ASSAY OF PROGESTERONE 17-D', 101.0, None, None],
#  ('saline', '83516'): ['IMMUNOASSAY NONANTIBODY', 116.007555, None, None],
#  ('saline', '83520'): ['IMMUNOASSAY QUANT NOS NONAB', 129.8, 43.5, None],
#  ('saline', '83525'): ['ASSAY OF INSULIN', 99.0, None, None],
#  ('saline', '83540'): ['ASSAY OF IRON', 79.0, 57.67, None],
#  ('saline', '83550'): ['IRON BINDING TEST', 68.0, 49.64, None],
#  ('saline', '83605'): ['ASSAY OF LACTIC ACID', 104.0, None, None],
#  ('saline', '83615'): ['LACTATE (LD) (LDH) ENZYME', 66.0, None, None],
#  ('saline', '83655'): ['ASSAY OF LEAD', 59.0, None, None],
#  ('saline', '83690'): ['ASSAY OF LIPASE', 82.0, None, None],
#  ('saline', '83735'): ['ASSAY OF MAGNESIUM', 79.0, 57.67, None],
#  ('saline', '83789'): ['MASS SPECTROMETRY QUAL/QUAN', 153.0, None, None],
#  ('saline', '83825'): ['ASSAY OF MERCURY', 62.0, None, None],
#  ('saline', '83835'): ['ASSAY OF METANEPHRINES', 263.0, None, None],
#  ('saline', '83874'): ['ASSAY OF MYOGLOBIN', 145.0, None, None],
#  ('saline', '83880'): ['ASSAY OF NATRIURETIC PEPTIDE', 216.0, None, None],
#  ('saline', '83921'): ['ORGANIC ACID SINGLE QUANT', 116.0, None, None],
#  ('saline', '83930'): ['ASSAY OF BLOOD OSMOLALITY', 61.0, None, None],
#  ('saline', '83970'): ['ASSAY OF PARATHORMONE', 182.0, None, None],
#  ('saline', '84075'): ['ASSAY ALKALINE PHOSPHATASE', 72.0, None, None],
#  ('saline', '84100'): ['ASSAY OF PHOSPHORUS', 44.0, None, None],
#  ('saline', '84112'): ['EVAL AMNIOTIC FLUID PROTEIN', 238.0, None, None],
#  ('saline', '84132'): ['ASSAY OF SERUM POTASSIUM', 46.0, None, None],
#  ('saline', '84133'): ['ASSAY OF URINE POTASSIUM', 42.0, None, None],
#  ('saline', '84134'): ['ASSAY OF PREALBUMIN', 102.0, None, None],
#  ('saline', '84143'): ['ASSAY OF 17-HYDROXYPREGNENO', 271.0, None, None],
#  ('saline', '84144'): ['ASSAY OF PROGESTERONE', 92.0, None, None],
#  ('saline', '84145'): ['PROCALCITONIN (PCT)', 97.0, None, None],
#  ('saline', '84146'): ['ASSAY OF PROLACTIN', 69.0, None, None],
#  ('saline', '84153'): ['ASSAY OF PSA TOTAL', 129.0, 96.75, None],
#  ('saline', '84155'): ['ASSAY OF PROTEIN SERUM', 36.0, None, None],
#  ('saline', '84156'): ['ASSAY OF PROTEIN URINE', 43.0, None, None],
#  ('saline', '84157'): ['ASSAY OF PROTEIN OTHER', 37.0, None, None],
#  ('saline', '84165'): ['PROTEIN E-PHORESIS SERUM', 89.0, None, None],
#  ('saline', '84166'): ['PROTEIN E-PHORESIS/URINE/CSF', 66.0, None, None],
#  ('saline', '84207'): ['ASSAY OF VITAMIN B-6', 258.0, None, None],
#  ('saline', '84244'): ['ASSAY OF RENIN', 198.0, None, None],
#  ('saline', '84255'): ['ASSAY OF SELENIUM', 173.0, None, None],
#  ('saline', '84295'): ['ASSAY OF SERUM SODIUM', 38.0, None, None],
#  ('saline', '84300'): ['ASSAY OF URINE SODIUM', 38.0, None, None],
#  ('saline', '84305'): ['ASSAY OF SOMATOMEDIN', 81.0, None, None],
#  ('saline', '84311'): ['SPECTROPHOTOMETRY', 145.0, None, None],
#  ('saline', '84402'): ['ASSAY OF FREE TESTOSTERONE', 268.0, 201.0, None],
#  ('saline', '84403'): ['ASSAY OF TOTAL TESTOSTERONE', 124.5, 96.75, None],
#  ('saline', '84425'): ['ASSAY OF VITAMIN B-1', 133.0, 97.09, None],
#  ('saline', '84432'): ['ASSAY OF THYROGLOBULIN', 71.0, None, None],
#  ('saline', '84436'): ['ASSAY OF TOTAL THYROXINE', 26.0, None, None],
#  ('saline', '84439'): ['ASSAY OF FREE THYROXINE', 100.0, 73.0, None],
#  ('saline', '84443'): ['ASSAY THYROID STIM HORMONE', 157.0, 114.61, 63.99],
#  ('saline', '84450'): ['TRANSFERASE (AST) (SGOT)', 60.0, None, None],
#  ('saline', '84460'): ['ALANINE AMINO (ALT) (SGPT)', 59.0, None, None],
#  ('saline', '84466'): ['ASSAY OF TRANSFERRIN', 56.0, 42.0, None],
#  ('saline', '84478'): ['ASSAY OF TRIGLYCERIDES', 70.0, None, None],
#  ('saline', '84480'): ['ASSAY TRIIODOTHYRONINE (T3)', 105.0, None, None],
#  ('saline', '84481'): ['FREE ASSAY (FT-3)', 75.0, 54.75, None],
#  ('saline', '84484'): ['ASSAY OF TROPONIN QUANT', 147.0, None, None],
#  ('saline', '84520'): ['ASSAY OF UREA NITROGEN', 47.0, None, None],
#  ('saline', '84550'): ['ASSAY OF BLOOD/URIC ACID', 56.0, None, None],
#  ('saline', '84585'): ['ASSAY OF URINE VMA', 83.0, None, None],
#  ('saline', '84630'): ['ASSAY OF ZINC', 50.0, 36.5, None],
#  ('saline', '84702'): ['CHORIONIC GONADOTROPIN TEST', 82.0, None, None],
#  ('saline', '84703'): ['CHORIONIC GONADOTROPIN ASSAY', 111.0, 83.25, None],
#  ('saline', '85014'): ['HEMATOCRIT', 23.0, 17.25, None],
#  ('saline', '85018'): ['HEMOGLOBIN', 32.0, 24.0, None],
#  ('saline', '85025'): ['COMPLETE CBC W/AUTO DIFF WBC', 76.0, 55.48, 29.62],
#  ('saline', '85027'): ['COMPLETE CBC AUTOMATED', 60.0, None, None],
#  ('saline', '85045'): ['AUTOMATED RETICULOCYTE COUNT', 34.0, None, None],
#  ('saline', '85048'): ['AUTOMATED LEUKOCYTE COUNT', 25.0, None, None],
#  ('saline', '85049'): ['AUTOMATED PLATELET COUNT', 57.714, None, None],
#  ('saline', '85303'): ['CLOT INHIBIT PROT C ACTIVITY', 179.0, None, None],
#  ('saline', '85306'): ['CLOT INHIBIT PROT S FREE', 215.0, None, None],
#  ('saline', '85379'): ['FIBRIN DEGRADATION QUANT', 126.0, None, None],
#  ('saline', '85385'): ['FIBRINOGEN ANTIGEN', 44.0, None, None],
#  ('saline', '85549'): ['MURAMIDASE', 69.0, None, None],
#  ('saline', '85610'): ['PROTHROMBIN TIME', 49.0, None, None],
#  ('saline', '85613'): ['RUSSELL VIPER VENOM DILUTED', 84.0, None, None],
#  ('saline', '85651'): ['RBC SED RATE NONAUTOMATED', 47.0, 35.25, None],
#  ('saline', '85730'): ['THROMBOPLASTIN TIME PARTIAL', 76.0, None, None],
#  ('saline', '86000'): ['AGGLUTININS FEBRILE ANTIGEN', 80.0, None, None],
#  ('saline', '86003'): ['ALLG SPEC IGE CRUDE XTRC EA', 51.86421, 14.25, None],
#  ('saline', '86021'): ['WBC ANTIBODY IDENTIFICATION', 110.0, None, None],
#  ('saline', '86038'): ['ANTINUCLEAR ANTIBODIES', 79.0, 59.25, None],
#  ('saline', '86039'): ['ANTINUCLEAR ANTIBODIES (ANA)', 49.0, None, None],
#  ('saline', '86060'): ['ANTISTREPTOLYSIN O TITER', 44.0, 32.12, None],
#  ('saline', '86140'): ['C-REACTIVE PROTEIN', 100.0, 75.0, None],
#  ('saline', '86146'): ['BETA-2 GLYCOPROTEIN ANTIBODY', 158.0, None, None],
#  ('saline', '86147'): ['CARDIOLIPIN ANTIBODY EA IG', 141.25, None, None],
#  ('saline', '86156'): ['COLD AGGLUTININ SCREEN', 131.0, None, None],
#  ('saline', '86160'): ['COMPLEMENT ANTIGEN', 123.75, None, None],
#  ('saline', '86162'): ['COMPLEMENT TOTAL (CH50)', 105.0, None, None],
#  ('saline', '86200'): ['CCP ANTIBODY', 132.0, None, None],
#  ('saline', '86215'): ['DEOXYRIBONUCLEASE ANTIBODY', 47.0, 34.31, None],
#  ('saline', '86225'): ['DNA ANTIBODY NATIVE', 77.0, None, None],
#  ('saline', '86235'): ['NUCLEAR ANTIGEN ANTIBODY', 106.0, None, None],
#  ('saline', '86255'): ['FLUORESCENT ANTIBODY SCREEN', 94.0, None, None],
#  ('saline', '86308'): ['HETEROPHILE ANTIBODY SCREEN', 28.0, None, None],
#  ('saline', '86317'): ['IMMUNOASSAY INFECTIOUS AGENT', 191.583333, None, None],
#  ('saline', '86334'): ['IMMUNOFIX E-PHORESIS SERUM', 84.0, None, None],
#  ('saline', '86335'): ['IMMUNFIX E-PHORSIS/URINE/CSF', 250.986666, None, None],
#  ('saline', '86360'): ['T CELL ABSOLUTE COUNT/RATIO', 158.0, None, None],
#  ('saline', '86376'): ['MICROSOMAL ANTIBODY EACH', 79.0, None, None],
#  ('saline', '86403'): ['PARTICLE AGGLUT ANTBDY SCRN', 47.05, None, None],
#  ('saline', '86430'): ['RHEUMATOID FACTOR TEST QUAL', 66.0, 49.5, None],
#  ('saline', '86480'): ['TB TEST CELL IMMUN MEASURE', 230.0, 167.9, None],
#  ('saline', '86592'): ['SYPHILIS TEST NON-TREP QUAL', 49.0, None, None],
#  ('saline', '86611'): ['BARTONELLA ANTIBODY', 80.675092, None, None],
#  ('saline', '86617'): ['LYME DISEASE ANTIBODY', 166.5, None, None],
#  ('saline', '86618'): ['LYME DISEASE ANTIBODY', 76.0, 55.48, None],
#  ('saline', '86638'): ['Q FEVER ANTIBODY', 45.0, None, None],
#  ('saline', '86644'): ['CMV ANTIBODY', 270.0, 197.1, None],
#  ('saline', '86645'): ['CMV ANTIBODY IGM', 74.0, 54.02, None],
#  ('saline', '86648'): ['DIPHTHERIA ANTIBODY', 55.0, None, None],
#  ('saline', '86658'): ['ENTEROVIRUS ANTIBODY', 123.142, 34.31, None],
#  ('saline', '86664'): ['EPSTEIN-BARR NUCLEAR ANTIGEN', 67.0, 48.91, None],
#  ('saline', '86665'): ['EPSTEIN-BARR CAPSID VCA', 86.0, 62.78, None],
#  ('saline', '86666'): ['EHRLICHIA ANTIBODY', 121.5, None, None],
#  ('saline', '86695'): ['HERPES SIMPLEX TYPE 1 TEST', 45.092857, None, None],
#  ('saline', '86696'): ['HERPES SIMPLEX TYPE 2 TEST', 86.0, None, None],
#  ('saline', '86704'): ['HEP B CORE ANTIBODY TOTAL', 94.0, None, None],
#  ('saline', '86705'): ['HEP B CORE ANTIBODY IGM', 80.0, None, None],
#  ('saline', '86711'): ['JOHN CUNNINGHAM ANTIBODY', 2848.25, None, None],
#  ('saline', '86738'): ['MYCOPLASMA ANTIBODY', 47.0, 34.31, None],
#  ('saline', '86747'): ['PARVOVIRUS ANTIBODY', 67.5, 49.275, None],
#  ('saline', '86753'): ['PROTOZOA ANTIBODY NOS', 46.0, None, None],
#  ('saline', '86757'): ['RICKETTSIA ANTIBODY', 71.0, None, None],
#  ('saline', '86762'): ['RUBELLA ANTIBODY', 69.0, None, None],
#  ('saline', '86774'): ['TETANUS ANTIBODY', 67.0, None, None],
#  ('saline', '86780'): ['TREPONEMA PALLIDUM', 78.0, None, None],
#  ('saline', '86790'): ['VIRUS ANTIBODY NOS', 107.8, None, None],
#  ('saline', '86800'): ['THYROGLOBULIN ANTIBODY', 70.0, None, None],
#  ('saline', '86803'): ['HEPATITIS C AB TEST', 123.0, None, None],
#  ('saline', '86812'): ['HLA TYPING A B OR C', 114.0, None, None],
#  ('saline', '86850'): ['RBC ANTIBODY SCREEN', 105.0, None, None],
#  ('saline', '86860'): ['RBC ANTIBODY ELUTION', 236.0, None, None],
#  ('saline', '86870'): ['RBC ANTIBODY IDENTIFICATION', 475.0, None, None],
#  ('saline', '86880'): ['COOMBS TEST DIRECT', 36.0, None, None],
#  ('saline', '86885'): ['COOMBS TEST INDIRECT QUAL', 133.0, 99.75, None],
#  ('saline', '86900'): ['BLOOD TYPING SEROLOGIC ABO', 66.0, None, None],
#  ('saline', '86901'): ['BLOOD TYPING SEROLOGIC RH(D)', 66.0, None, None],
#  ('saline', '86902'): ['BLOOD TYPE ANTIGEN DONOR EA', 214.461538, None, None],
#  ('saline', '86920'): ['COMPATIBILITY TEST SPIN', 133.0, None, None],
#  ('saline', '86921'): ['COMPATIBILITY TEST INCUBATE', 133.0, 99.75, None],
#  ('saline', '86922'): ['COMPATIBILITY TEST ANTIGLOB', 190.105263, None, None],
#  ('saline', '86927'): ['PLASMA FRESH FROZEN', 223.0, None, None],
#  ('saline', '86940'): ['HEMOLYSINS/AGGLUTININS AUTO', 36.0, None, None],
#  ('saline', '86970'): ['RBC PRETX INCUBATJ W/CHEMICL', 100.0, None, None],
#  ('saline', '87040'): ['BLOOD CULTURE FOR BACTERIA', 126.0, None, None],
#  ('saline', '87045'): ['FECES CULTURE AEROBIC BACT', 92.0, 69.0, None],
#  ('saline', '87046'): ['STOOL CULTR AEROBIC BACT EA', 27.2, 20.4, None],
#  ('saline', '87070'): ['CULTURE OTHR SPECIMN AEROBIC', 118.0, None, None],
#  ('saline', '87075'): ['CULTR BACTERIA EXCEPT BLOOD', 132.0, None, None],
#  ('saline', '87076'): ['CULTURE ANAEROBE IDENT EACH', 111.0, None, None],
#  ('saline', '87077'): ['CULTURE AEROBIC IDENTIFY', 65.0, 47.45, None],
#  ('saline', '87081'): ['CULTURE SCREEN ONLY', 34.0, None, None],
#  ('saline', '87086'): ['URINE CULTURE/COLONY COUNT', 75.0, None, 30.77],
#  ('saline', '87088'): ['URINE BACTERIA CULTURE', 85.0, 62.05, None],
#  ('saline', '87102'): ['FUNGUS ISOLATION CULTURE', 79.0, None, None],
#  ('saline', '87150'): ['DNA/RNA AMPLIFIED PROBE', 125.0, None, None],
#  ('saline', '87177'): ['OVA AND PARASITES SMEARS', 55.0, 41.25, None],
#  ('saline', '87181'): ['MICROBE SUSCEPTIBLE DIFFUSE', 77.444444, 45.99, None],
#  ('saline', '87186'): ['MICROBE SUSCEPTIBLE MIC', 67.0, None, None],
#  ('saline', '87205'): ['SMEAR GRAM STAIN', 44.0, None, None],
#  ('saline', '87206'): ['SMEAR FLUORESCENT/ACID STAI', 59.0, None, None],
#  ('saline', '87209'): ['SMEAR COMPLEX STAIN', 49.0, 36.75, None],
#  ('saline', '87210'): ['SMEAR WET MOUNT SALINE/INK', 29.0, None, None],
#  ('saline', '87324'): ['CLOSTRIDIUM AG IA', 32.28, 24.21, None],
#  ('saline', '87328'): ['CRYPTOSPORIDIUM AG IA', 53.0, 39.75, None],
#  ('saline', '87329'): ['GIARDIA AG IA', 53.0, 39.75, None],
#  ('saline', '87335'): ['E COLI 0157 AG IA', 98.0, None, None],
#  ('saline', '87337'): ['ENTAMOEB HIST GROUP AG IA', 92.0, None, None],
#  ('saline', '87338'): ['HPYLORI STOOL IA', 105.0, None, None],
#  ('saline', '87340'): ['HEPATITIS B SURFACE AG IA', 78.0, None, None],
#  ('saline', '87389'): ['HIV-1 AG W/HIV-1 & HIV-2 AB', 143.0, None, None],
#  ('saline', '87425'): ['ROTAVIRUS AG IA', 82.0, 61.5, None],
#  ('saline', '87449'): ['AG DETECT NOS IA MULT', 32.28, 24.21, None],
#  ('saline', '87491'): ['CHYLMD TRACH DNA AMP PROBE', 154.0, None, None],
#  ('saline', '87497'): ['CYTOMEG DNA QUANT', 185.0, None, None],
#  ('saline', '87502'): ['INFLUENZA DNA AMP PROBE', 276.0, None, None],
#  ('saline', '87517'): ['HEPATITIS B DNA QUANT', 250.0, None, None],
#  ('saline', '87521'): ['HEPATITIS C PROBE&RVRS TRNSC', 318.0, None, None],
#  ('saline', '87522'): ['HEPATITIS C REVRS TRNSCRPJ', 279.0, None, None],
#  ('saline', '87529'): ['HSV DNA AMP PROBE', 260.0, None, None],
#  ('saline', '87536'): ['HIV-1 QUANT&REVRSE TRNSCRPJ', 375.0, None, None],
#  ('saline', '87591'): ['N.GONORRHOEAE DNA AMP PROB', 154.0, None, None],
#  ('saline', '87635'): ['SARS-COV-2 COVID-19 AMP PRB', 217.0, 111.844782, None],
#  ('saline', '87640'): ['STAPH A DNA AMP PROBE', 125.0, None, None],
#  ('saline', '87641'): ['MR-STAPH DNA AMP PROBE', 125.0, None, None],
#  ('saline', '87661'): ['TRICHOMONAS VAGINALIS AMPLIF', 114.0, None, None],
#  ('saline', '87798'): ['DETECT AGENT NOS DNA AMP', 236.0, None, None],
#  ('saline', '87801'): ['DETECT AGNT MULT DNA AMPLI', 325.0, None, None],
#  ('saline', '87807'): ['RSV ASSAY W/OPTIC', 85.0, None, None],
#  ('saline', '87880'): ['STREP A ASSAY W/OPTIC', 95.0, None, None],
#  ('saline', '87899'): ['AGENT NOS ASSAY W/OPTIC', 130.0, 94.9, None],
#  ('saline', '87902'): ['GENOTYPE DNA/RNA HEP C', 927.0, None, None],
#  ('saline', '88300'): ['SURGICAL PATH GROSS', 27.0, None, None],
#  ('saline', '88302'): ['TISSUE EXAM BY PATHOLOGIST', 42.0, None, None],
#  ('saline', '88304'): ['TISSUE EXAM BY PATHOLOGIST', 90.0, None, None],
#  ('saline', '88305'): ['TISSUE EXAM BY PATHOLOGIST', 90.0, None, None],
#  ('saline', '88307'): ['TISSUE EXAM BY PATHOLOGIST', 141.0, None, None],
#  ('saline', '88311'): ['DECALCIFY TISSUE', 27.0, None, None],
#  ('saline', '88313'): ['SPECIAL STAINS GROUP 2', 42.5, None, None],
#  ('saline', '88341'): ['IMMUNOHISTO ANTB ADDL SLIDE', 90.0, None, None],
#  ('saline', '88342'): ['IMMUNOHISTO ANTB 1ST STAIN', 90.0, None, None],
#  ('saline', '88346'): ['IMMUNOFLUOR ANTB 1ST STAIN', 79.0, None, None],
#  ('saline', '88350'): ['IMMUNOFLUOR ANTB ADDL STAIN', 75.0, None, None],
#  ('saline', '89050'): ['BODY FLUID CELL COUNT', 32.0, None, None],
#  ('saline', '89051'): ['BODY FLUID CELL COUNT', 54.0, None, None],
#  ('saline', '89055'): ['LEUKOCYTE ASSESSMENT FECAL', 23.0, 17.25, None],
#  ('saline', '89060'): ['EXAM SYNOVIAL FLUID CRYSTALS', 43.0, None, None],
#  ('saline', '90471'): ['IMMUNIZATION ADMIN', 167.0, None, None],
#  ('saline', '90656'): ['IIV3 VACC NO PRSV 0.5 ML IM', 56.0, None, None],
#  ('saline', '90686'): ['IIV4 VACC NO PRSV 0.5 ML IM', 70.558333, None, None],
#  ('saline', '90714'): ['TD VACC NO PRESV 7 YRS+ IM', 87.11, None, None],
#  ('saline', '90715'): ['TDAP VACCINE 7 YRS/> IM', 155.94, None, None],
#  ('saline', '90732'): ['PPSV23 VACC 2 YRS+ SUBQ/IM', 249.35, None, None],
#  ('saline', '92507'): ['SPEECH/HEARING THERAPY', 197.0, None, None],
#  ('saline', '92522'): ['EVALUATE SPEECH PRODUCTION', 229.0, None, None],
#  ('saline', '92523'): ['SPEECH SOUND LANG COMPREHEN', 488.0, None, None],
#  ('saline', '92524'): ['BEHAVRAL QUALIT ANALYS VOICE', 236.0, None, None],
#  ('saline', '92526'): ['ORAL FUNCTION THERAPY', 214.0, None, 120.79],
#  ('saline', '92610'): ['EVALUATE SWALLOWING FUNCTION', 213.0, None, 120.41],
#  ('saline', '92611'): ['MOTION FLUOROSCOPY/SWALLOW', 224.0, None, None],
#  ...}

# %%
for code,charge in wr_charges.items():
    saline = sal_charges.get(('saline',code[1]))
    if not saline is None:
        print(code,charge,saline)
# Out:
# ('whiteriver', '10060') ['DRAINAGE OF SKIN ABSCESS', 11506.95, 10126.116, 6443.892] ['DRAINAGE OF SKIN ABSCESS', 3406.7896, 129.19, 1274.0]
# ('whiteriver', '10061') ['DRAINAGE OF SKIN ABSCESS', 472.0, 415.36, 264.32] ['DRAINAGE OF SKIN ABSCESS', 3057.258571, None, None]
# ('whiteriver', '10120') ['REMOVE FOREIGN BODY', 732.0, 644.16, 409.92] ['REMOVE FOREIGN BODY', 5229.0, None, None]
# ('whiteriver', '10140') ['DRAINAGE OF HEMATOMA/FLUID', 8004.01, 7043.5288, 4482.2456] ['DRAINAGE OF HEMATOMA/FLUID', 4236.7, None, None]
# ('whiteriver', '10160') ['PUNCTURE DRAINAGE OF LESION', 1826.0, 1606.88, 1022.56] ['PUNCTURE DRAINAGE OF LESION', 878.0, None, None]
# ('whiteriver', '11010') ['DEBRIDE SKIN AT FX SITE', 34515.83, 30373.9304, 19328.8648] ['DEBRIDE SKIN AT FX SITE', 5871.153333, None, None]
# ('whiteriver', '11011') ['DEBRIDE SKIN MUSC AT FX SIT', 1405.0, 1236.4, 786.8] ['DEBRIDE SKIN MUSC AT FX SITE', 3615.5, None, None]
# ('whiteriver', '11042') ['DEB SUBQ TISSUE 20 SQ CM/<', 8412.01, 7402.5688, 4710.7256] ['DEB SUBQ TISSUE 20 SQ CM/<', 878.0, None, 836.0]
# ('whiteriver', '11043') ['DEB MUSC/FASCIA 20 SQ CM/<', 15584.61, 13714.4568, 8727.3816] ['DEB MUSC/FASCIA 20 SQ CM/<', 2087.509375, None, None]
# ('whiteriver', '11044') ['DEB BONE 20 SQ CM/<', 7210.93, 6345.6184, 4038.1208] ['DEB BONE 20 SQ CM/<', 6192.24, None, None]
# ('whiteriver', '11055') ['TRIM SKIN LESION', 428.0, 376.64, 239.68] ['TRIM SKIN LESION', 493.0, None, None]
# ('whiteriver', '11056') ['TRIM SKIN LESIONS 2 TO 4', 428.0, 376.64, 239.68] ['TRIM SKIN LESIONS 2 TO 4', 493.0, None, None]
# ('whiteriver', '11400') ['EXC TR-EXT B9+MARG 0.5 CM<', 1106.0, 973.28, 619.36] ['EXC TR-EXT B9+MARG 0.5 CM<', 4354.395833, 461.083333, None]
# ('whiteriver', '11401') ['EXC TR-EXT B9+MARG 0.6-1 CM', 601.0, 528.88, 336.56] ['EXC TR-EXT B9+MARG 0.6-1 CM', 4382.793333, None, None]
# ('whiteriver', '11402') ['EXC TR-EXT B9+MARG 1.1-2 CM', 1405.0, 1236.4, 786.8] ['EXC TR-EXT B9+MARG 1.1-2 CM', 3713.400909, 216.75, None]
# ('whiteriver', '11403') ['EXC TR-EXT B9+MARG 2.1-3CM', 15553.61, 13687.1768, 8710.0216] ['EXC TR-EXT B9+MARG 2.1-3CM', 3971.928888, 289.0, None]
# ('whiteriver', '11404') ['EXC TR-EXT B9+MARG 3.1-4 CM', 5513.75, 4852.1, 3087.7] ['EXC TR-EXT B9+MARG 3.1-4 CM', 3293.79, None, None]
# ('whiteriver', '11406') ['EXC TR-EXT B9+MARG >4.0 CM', 7326.42, 6447.2496, 4102.7952] ['EXC TR-EXT B9+MARG >4.0 CM', 5415.72, None, None]
# ('whiteriver', '11420') ['EXC H-F-NK-SP B9+MARG 0.5/<', 3092.0, 2720.96, 1731.52] ['EXC H-F-NK-SP B9+MARG 0.5/<', 3111.8, None, None]
# ('whiteriver', '11421') ['EXC H-F-NK-SP B9+MARG 0.6-1', 7638.11, 6721.5368, 4277.3416] ['EXC H-F-NK-SP B9+MARG 0.6-1', 2139.33, None, None]
# ('whiteriver', '11422') ['EXC H-F-NK-SP B9+MARG 1.1-2', 7291.86, 6416.8368, 4083.4416] ['EXC H-F-NK-SP B9+MARG 1.1-2', 3569.366, None, None]
# ('whiteriver', '11602') ['EXC TR-EXT MAL+MARG 1.1-2 C', 6988.55, 6149.924, 3913.588] ['EXC TR-EXT MAL+MARG 1.1-2 CM', 3757.75, None, None]
# ('whiteriver', '11623') ['EXC S/N/H/F/G MAL+MRG 2.1-3', 3091.55, 2720.564, 1731.268] ['EXC S/N/H/F/G MAL+MRG 2.1-3', 6213.0, None, None]
# ('whiteriver', '11750') ['REMOVAL OF NAIL BED', 3809.3, 3352.184, 2133.208] ['REMOVAL OF NAIL BED', 1302.55, None, None]
# ('whiteriver', '11760') ['REPAIR OF NAIL BED', 7498.8, 6598.944, 4199.328] ['REPAIR OF NAIL BED', 3725.75, None, None]
# ('whiteriver', '12001') ['RPR S/N/AX/GEN/TRNK 2.5CM/<', 428.0, 376.64, 239.68] ['RPR S/N/AX/GEN/TRNK 2.5CM/<', 1181.965932, None, None]
# ('whiteriver', '12002') ['RPR S/N/AX/GEN/TRNK2.6-7.5C', 428.0, 376.64, 239.68] ['RPR S/N/AX/GEN/TRNK2.6-7.5CM', 1145.854848, None, None]
# ('whiteriver', '12011') ['RPR F/E/E/N/L/M 2.5 CM/<', 428.0, 376.64, 239.68] ['RPR F/E/E/N/L/M 2.5 CM/<', 1763.839268, None, None]
# ('whiteriver', '12031') ['INTMD RPR S/A/T/EXT 2.5 CM/', 6988.55, 6149.924, 3913.588] ['INTMD RPR S/A/T/EXT 2.5 CM/<', 3360.0, None, None]
# ('whiteriver', '12032') ['INTMD RPR S/A/T/EXT 2.6-7.5', 12062.49, 10614.9912, 6754.9944] ['INTMD RPR S/A/T/EXT 2.6-7.5', 2228.7425, None, None]
# ('whiteriver', '12034') ['INTMD RPR S/TR/EXT 7.6-12.5', 10235.79, 9007.4952, 5732.0424] ['INTMD RPR S/TR/EXT 7.6-12.5', 5014.75, None, None]
# ('whiteriver', '12052') ['INTMD RPR FACE/MM 2.6-5.0 C', 513.0, 451.44, 287.28] ['INTMD RPR FACE/MM 2.6-5.0 CM', 2684.42, None, None]
# ('whiteriver', '13160') ['LATE CLOSURE OF WOUND', 14713.57, 12947.9416, 8239.5992] ['LATE CLOSURE OF WOUND', 7003.135, None, None]
# ('whiteriver', '15002') ['WOUND PREP TRK/ARM/LEG', 12599.08, 11087.1904, 7055.4848] ['WOUND PREP TRK/ARM/LEG', 13195.12, None, None]
# ('whiteriver', '15271') ['SKIN SUB GRAFT TRNK/ARM/LEG', 12599.08, 11087.1904, 7055.4848] ['SKIN SUB GRAFT TRNK/ARM/LEG', 16478.71, None, None]
# ('whiteriver', '15275') ['SKIN SUB GRAFT FACE/NK/HF/G', 3656.0, 3217.28, 2047.36] ['SKIN SUB GRAFT FACE/NK/HF/G', 4327.0, None, None]
# ('whiteriver', '16020') ['DRESS/DEBRID P-THICK BURN S', 428.0, 376.64, 239.68] ['DRESS/DEBRID P-THICK BURN S', 1154.25, None, None]
# ('whiteriver', '17110') ['DESTRUCT B9 LESION 1-14', 315.0, 277.2, 176.4] ['DESTRUCT B9 LESION 1-14', 492.0, None, None]
# ('whiteriver', '17250') ['CHEM CAUT OF GRANLTJ TISSUE', 441.0, 388.08, 246.96] ['CHEM CAUT OF GRANLTJ TISSUE', 492.0, None, None]
# ('whiteriver', '19000') ['DRAINAGE OF BREAST LESION', 4583.0, 4033.04, 2566.48] ['DRAINAGE OF BREAST LESION', 1618.0, None, None]

# %% [markdown]
# ---
# ---
#
# ### STRETCH from March 2020 - For those looking for an additional challenge
#
# The Coronavirus is creating quite the stir right now.  There are some sources suggesting that trends show it is going to be significantly more serious than SARS was back in the 2002 timeframe.  Here's one visualization trying to demonstrate that: https://www.reddit.com/r/China_Flu/comments/ev2b4v/i_updated_some_charts_comparing_this_outbreak/
#
# Someone on Kaggle has generously already compiled a dataset based on information from Johns Hopkins about the Coronavirus outbreak.  https://www.kaggle.com/brendaso/2019-coronavirus-dataset-01212020-01262020  Create a Kaggle account, if you don't already have one.  Download this data set and then upload it to your Jupyter Home folder.  (The "up arrow" button is for uploading a file.)
#
# Use Python's built-in `csv` module to read the data from this file and generate the following information: **what are the total confirmed cases in all of Mainland China as of the latest information in the data set?**  Some important things to note:
# * Each entry for a given city has the **cumulative** number of cases.  So that column is not additive (it cannot be summed).  You'll have to find a way to filter your data for the last day for each city, then total those up.
# * If you choose to parse the date column, you will want to lookup how to do that using Python's `datetime` module.  Especially the `strptime` function.  https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior  Hint: you can parse a date string in the format 2/17/2020 using the code below.  This link will tell you what things like `%m` and `%Y` mean.
#
# ```
# from datetime import datetime
# d = datetime.strptime('2/17/2020', '%m/%d/%Y')
# ```
#
# If you want to take this another step, **create a list of tuples that contain (observate date, total confirmed) totalled over all locations represented in the data**

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week06_assignment_2.ipynb
# git commit -a -m "Submitting the week 6 programming assignment"
# git push

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 6 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
