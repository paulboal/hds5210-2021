# %% [markdown]
# # Merging DataFrames Together
#
# In this module, we're going to talk about two different types of merging: concatenation and masking

# %%
import pandas as pd

# %% [markdown]
# ## Concatenation
#
# To "concatenate" means to combine things end-to-end.  That is, we're going to merge together multiple data sets in a way that we just keep appending more rows end-on-end.
#
# In `/data/drinking/` there are a whole list of files that we want to merge together into a single data frame.  They all have the same format, but the are from different cities.

# %%
# First, we can get a list of the files that are in a particular directory using the os package
import os
files = os.listdir('/data/drinking/')

# %%
files
# Out:
# ['Fort_Worth_Tarrant_County_TX.csv',
#  'Las_Vegas_Clark_County_NV.csv',
#  'Long_Beach_CA.csv',
#  'Oakland_Alameda_County_CA.csv',
#  'San_Antonio_TX.csv',
#  'Boston_MA.csv',
#  'Charlotte_NC.csv',
#  'Philadelphia_PA.csv',
#  'Los_Angeles_CA.csv',
#  'San_Diego_County_CA.csv',
#  'Indianapolis_Marion_County_IN.csv',
#  'San_Jose_CA.csv',
#  'Columbus_OH.csv',
#  'Minneapolis_MN.csv',
#  'Seattle_WA.csv',
#  'Miami_Miami-Dade_County_FL.csv',
#  'Kansas_City_MO.csv',
#  'Detroit_MI.csv',
#  'Washington_DC.csv',
#  'Phoenix_AZ.csv',
#  'New_York_City_NY.csv',
#  'Portland_Multnomah_County_OR.csv',
#  'U.S._Total_U.S._Total.csv',
#  'Houston_TX.csv',
#  'Denver_CO.csv',
#  'Chicago_Il.csv',
#  'Baltimore_MD.csv']

# %%
len(files)
# Out:
# 27

# %%
# Then, let's read each of those files into their own df and store that in a list of dfs
dataframes = []

# %%
for f in files:
    df = pd.read_csv('/data/drinking/'+f)
    dataframes.append(df)

# %%
len(dataframes)
# Out:
# 27

# %%
type(dataframes[0])
# Out:
# pandas.core.frame.DataFrame

# %%
dataframes[0].head()
# Out:
#    Unnamed: 0                 Indicator Category  \
# 0          15  Behavioral Health/Substance Abuse
# 1         128  Behavioral Health/Substance Abuse
# 2         180  Behavioral Health/Substance Abuse
# 3         354  Behavioral Health/Substance Abuse
# 4         400  Behavioral Health/Substance Abuse
#
#                            Indicator  Year   Sex Race/Ethnicity  Value  \
# 0  Percent of Adults Who Binge Drank  2010  Both            All   15.3
# 1  Percent of Adults Who Binge Drank  2011  Both            All   19.7
# 2  Percent of Adults Who Binge Drank  2012  Both            All   17.7
# 3  Percent of Adults Who Binge Drank  2013  Both            All   14.6
# 4  Percent of Adults Who Binge Drank  2014  Both            All   13.4
#
#                              Place  \
# 0  Fort Worth (Tarrant County), TX
# 1  Fort Worth (Tarrant County), TX
# 2  Fort Worth (Tarrant County), TX
# 3  Fort Worth (Tarrant County), TX
# 4  Fort Worth (Tarrant County), TX
#
#                           BCHC Requested Methodology  \
# 0  BRFSS (or similar) How many times during the p...
# 1  BRFSS (or similar) How many times during the p...
# 2  BRFSS (or similar) How many times during the p...
# 3  BRFSS (or similar) How many times during the p...
# 4  BRFSS (or similar) How many times during the p...
#
#                                               Source  Methods  \
# 0  Behavior Risk Factors: Selected Metropolitan A...      NaN
# 1  Behavior Risk Factors: Selected Metropolitan A...      NaN
# 2  Behavior Risk Factors: Selected Metropolitan A...      NaN
# 3  Centers for Disease Control and Prevention, Na...      NaN
# 4  Centers for Disease Control and Prevention, Na...      NaN
#
#                                                Notes  \
# 0               Tarrant County (not just Fort Worth)
# 1               Tarrant County (not just Fort Worth)
# 2               Tarrant County (not just Fort Worth)
# 3  FW-Arlington Metropolitan Division includes re...
# 4  FW-Arlington Metropolitan Division includes re...
#
#    90% Confidence Level - Low  90% Confidence Level - High  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    95% Confidence Level - Low  95% Confidence Level - High
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                        11.0                         18.2
# 4                         9.4                         17.3

# %%
len(dataframes)
# Out:
# 27

# %%
# Then we can concatenate them together with pd.concat
drinking = pd.concat(dataframes)

# %% [markdown]
# Let's check to make sure the counts match up...
#
# Length of combined dataframe == Sum of the length of the individual dataframes?

# %%
len(drinking)
# Out:
# 599

# %%
sum([len(x) for x in dataframes])
# Out:
# 599

# %%
drinking.head()
# Out:
#    Unnamed: 0                 Indicator Category  \
# 0          15  Behavioral Health/Substance Abuse
# 1         128  Behavioral Health/Substance Abuse
# 2         180  Behavioral Health/Substance Abuse
# 3         354  Behavioral Health/Substance Abuse
# 4         400  Behavioral Health/Substance Abuse
#
#                            Indicator  Year   Sex Race/Ethnicity  Value  \
# 0  Percent of Adults Who Binge Drank  2010  Both            All   15.3
# 1  Percent of Adults Who Binge Drank  2011  Both            All   19.7
# 2  Percent of Adults Who Binge Drank  2012  Both            All   17.7
# 3  Percent of Adults Who Binge Drank  2013  Both            All   14.6
# 4  Percent of Adults Who Binge Drank  2014  Both            All   13.4
#
#                              Place  \
# 0  Fort Worth (Tarrant County), TX
# 1  Fort Worth (Tarrant County), TX
# 2  Fort Worth (Tarrant County), TX
# 3  Fort Worth (Tarrant County), TX
# 4  Fort Worth (Tarrant County), TX
#
#                           BCHC Requested Methodology  \
# 0  BRFSS (or similar) How many times during the p...
# 1  BRFSS (or similar) How many times during the p...
# 2  BRFSS (or similar) How many times during the p...
# 3  BRFSS (or similar) How many times during the p...
# 4  BRFSS (or similar) How many times during the p...
#
#                                               Source Methods  \
# 0  Behavior Risk Factors: Selected Metropolitan A...     NaN
# 1  Behavior Risk Factors: Selected Metropolitan A...     NaN
# 2  Behavior Risk Factors: Selected Metropolitan A...     NaN
# 3  Centers for Disease Control and Prevention, Na...     NaN
# 4  Centers for Disease Control and Prevention, Na...     NaN
#
#                                                Notes  \
# 0               Tarrant County (not just Fort Worth)
# 1               Tarrant County (not just Fort Worth)
# 2               Tarrant County (not just Fort Worth)
# 3  FW-Arlington Metropolitan Division includes re...
# 4  FW-Arlington Metropolitan Division includes re...
#
#    90% Confidence Level - Low  90% Confidence Level - High  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    95% Confidence Level - Low  95% Confidence Level - High
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                        11.0                         18.2
# 4                         9.4                         17.3

# %% [markdown]
# It's also possible to label the rows as they get concatenated together.  That can be handy if you want to keep track of which input file each row came from.

# %%
drinking2 = pd.concat(dataframes, keys=files)

# %%
drinking2.head()
# Out:
#                                     Unnamed: 0  \
# Fort_Worth_Tarrant_County_TX.csv 0          15
#                                  1         128
#                                  2         180
#                                  3         354
#                                  4         400
#
#                                                    Indicator Category  \
# Fort_Worth_Tarrant_County_TX.csv 0  Behavioral Health/Substance Abuse
#                                  1  Behavioral Health/Substance Abuse
#                                  2  Behavioral Health/Substance Abuse
#                                  3  Behavioral Health/Substance Abuse
#                                  4  Behavioral Health/Substance Abuse
#
#                                                             Indicator  Year  \
# Fort_Worth_Tarrant_County_TX.csv 0  Percent of Adults Who Binge Drank  2010
#                                  1  Percent of Adults Who Binge Drank  2011
#                                  2  Percent of Adults Who Binge Drank  2012
#                                  3  Percent of Adults Who Binge Drank  2013
#                                  4  Percent of Adults Who Binge Drank  2014
#
#                                      Sex Race/Ethnicity  Value  \
# Fort_Worth_Tarrant_County_TX.csv 0  Both            All   15.3
#                                  1  Both            All   19.7
#                                  2  Both            All   17.7
#                                  3  Both            All   14.6
#                                  4  Both            All   13.4
#
#                                                               Place  \
# Fort_Worth_Tarrant_County_TX.csv 0  Fort Worth (Tarrant County), TX
#                                  1  Fort Worth (Tarrant County), TX
#                                  2  Fort Worth (Tarrant County), TX
#                                  3  Fort Worth (Tarrant County), TX
#                                  4  Fort Worth (Tarrant County), TX
#
#                                                            BCHC Requested Methodology  \
# Fort_Worth_Tarrant_County_TX.csv 0  BRFSS (or similar) How many times during the p...
#                                  1  BRFSS (or similar) How many times during the p...
#                                  2  BRFSS (or similar) How many times during the p...
#                                  3  BRFSS (or similar) How many times during the p...
#                                  4  BRFSS (or similar) How many times during the p...
#
#                                                                                Source  \
# Fort_Worth_Tarrant_County_TX.csv 0  Behavior Risk Factors: Selected Metropolitan A...
#                                  1  Behavior Risk Factors: Selected Metropolitan A...
#                                  2  Behavior Risk Factors: Selected Metropolitan A...
#                                  3  Centers for Disease Control and Prevention, Na...
#                                  4  Centers for Disease Control and Prevention, Na...
#
#                                    Methods  \
# Fort_Worth_Tarrant_County_TX.csv 0     NaN
#                                  1     NaN
#                                  2     NaN
#                                  3     NaN
#                                  4     NaN
#
#                                                                                 Notes  \
# Fort_Worth_Tarrant_County_TX.csv 0               Tarrant County (not just Fort Worth)
#                                  1               Tarrant County (not just Fort Worth)
#                                  2               Tarrant County (not just Fort Worth)
#                                  3  FW-Arlington Metropolitan Division includes re...
#                                  4  FW-Arlington Metropolitan Division includes re...
#
#                                     90% Confidence Level - Low  \
# Fort_Worth_Tarrant_County_TX.csv 0                         NaN
#                                  1                         NaN
#                                  2                         NaN
#                                  3                         NaN
#                                  4                         NaN
#
#                                     90% Confidence Level - High  \
# Fort_Worth_Tarrant_County_TX.csv 0                          NaN
#                                  1                          NaN
#                                  2                          NaN
#                                  3                          NaN
#                                  4                          NaN
#
#                                     95% Confidence Level - Low  \
# Fort_Worth_Tarrant_County_TX.csv 0                         NaN
#                                  1                         NaN
#                                  2                         NaN
#                                  3                        11.0
#                                  4                         9.4
#
#                                     95% Confidence Level - High
# Fort_Worth_Tarrant_County_TX.csv 0                          NaN
#                                  1                          NaN
#                                  2                          NaN
#                                  3                         18.2
#                                  4                         17.3

# %%
drinking2.head().reset_index()
# Out:
#                             level_0  level_1  Unnamed: 0  \
# 0  Fort_Worth_Tarrant_County_TX.csv        0          15
# 1  Fort_Worth_Tarrant_County_TX.csv        1         128
# 2  Fort_Worth_Tarrant_County_TX.csv        2         180
# 3  Fort_Worth_Tarrant_County_TX.csv        3         354
# 4  Fort_Worth_Tarrant_County_TX.csv        4         400
#
#                   Indicator Category                          Indicator  Year  \
# 0  Behavioral Health/Substance Abuse  Percent of Adults Who Binge Drank  2010
# 1  Behavioral Health/Substance Abuse  Percent of Adults Who Binge Drank  2011
# 2  Behavioral Health/Substance Abuse  Percent of Adults Who Binge Drank  2012
# 3  Behavioral Health/Substance Abuse  Percent of Adults Who Binge Drank  2013
# 4  Behavioral Health/Substance Abuse  Percent of Adults Who Binge Drank  2014
#
#     Sex Race/Ethnicity  Value                            Place  \
# 0  Both            All   15.3  Fort Worth (Tarrant County), TX
# 1  Both            All   19.7  Fort Worth (Tarrant County), TX
# 2  Both            All   17.7  Fort Worth (Tarrant County), TX
# 3  Both            All   14.6  Fort Worth (Tarrant County), TX
# 4  Both            All   13.4  Fort Worth (Tarrant County), TX
#
#                           BCHC Requested Methodology  \
# 0  BRFSS (or similar) How many times during the p...
# 1  BRFSS (or similar) How many times during the p...
# 2  BRFSS (or similar) How many times during the p...
# 3  BRFSS (or similar) How many times during the p...
# 4  BRFSS (or similar) How many times during the p...
#
#                                               Source Methods  \
# 0  Behavior Risk Factors: Selected Metropolitan A...     NaN
# 1  Behavior Risk Factors: Selected Metropolitan A...     NaN
# 2  Behavior Risk Factors: Selected Metropolitan A...     NaN
# 3  Centers for Disease Control and Prevention, Na...     NaN
# 4  Centers for Disease Control and Prevention, Na...     NaN
#
#                                                Notes  \
# 0               Tarrant County (not just Fort Worth)
# 1               Tarrant County (not just Fort Worth)
# 2               Tarrant County (not just Fort Worth)
# 3  FW-Arlington Metropolitan Division includes re...
# 4  FW-Arlington Metropolitan Division includes re...
#
#    90% Confidence Level - Low  90% Confidence Level - High  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    95% Confidence Level - Low  95% Confidence Level - High
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                        11.0                         18.2
# 4                         9.4                         17.3

# %%
drinking2.index.levels[0]

# %% [markdown]
# ## Concatenating Side-by-Side
#
# The stacking example above is more common, but it might be interesting to concatenate data side-by-side.

# %%
names1=[['Paul','Boal'],['Anny', 'Monroe'],['Eric','Westhus'],['Andy','Slavitt']]
names2=[['Paul Boal'],['Anny Monroe'],['Eric Westhus'],[''],['Mario Garza']]
n1 = pd.DataFrame(names1, columns=['First','Last'])
n2 = pd.DataFrame(names2, columns=['Full Name'])

# %%
n1
# Out:
#   First     Last
# 0  Paul     Boal
# 1  Anny   Monroe
# 2  Eric  Westhus
# 3  Andy  Slavitt

# %%
n2
# Out:
#       Full Name
# 0     Paul Boal
# 1   Anny Monroe
# 2  Eric Westhus
# 3
# 4   Mario Garza

# %%
pd.concat([n1,n2], axis=1)
# Out:
#   First     Last     Full Name
# 0  Paul     Boal     Paul Boal
# 1  Anny   Monroe   Anny Monroe
# 2  Eric  Westhus  Eric Westhus
# 3  Andy  Slavitt
# 4   NaN      NaN   Mario Garza

# %% [markdown]
# ## Masking
#
# With "masking", we are taking two data sets and overlaying one ontop of the other.  If the first has values, then those will be kept.  If the first has a blank (NaN), then the underlying value from the next data set will be shown.

# %%
nppes1 = pd.read_csv('/data/nppes1.csv')
nppes2 = pd.read_csv('/data/nppes2.csv')
nppes1.set_index('NPI', inplace=True)
nppes2.set_index('NPI', inplace=True)

# %%
nppes2.head()
# Out:
#             Entity Type Code Provider Organization Name (Legal Business Name)  \
# NPI
# 1710950183                 1                                              NaN
# 1740769413                 1                                              NaN
# 1164984100                 1                                              NaN
# 1497217442                 2                           HEALTHSTAT CLINICS LLC
# 1841752896                 1                                              NaN
#
#            Provider Last Name (Legal Name) Provider First Name  \
# NPI
# 1710950183                 JIMENEZ MORALES                 LUZ
# 1740769413                   RIVERA TORRES             NOELLIE
# 1164984100                       LUGO JOSE             YADHIRA
# 1497217442                             NaN                 NaN
# 1841752896                              DU           XIAO ZHOU
#
#            Provider Middle Name        City State
# NPI
# 1710950183                    M  SAN GERMAN    PR
# 1740769413                MARIE    SAN JUAN    PR
# 1164984100                  NaN       PONCE    PR
# 1497217442                  NaN   VEGA BAJA    PR
# 1841752896                  NaN    WINNIPEG    MB

# %%
nppes1['State'].count()
# Out:
# 18699

# %%
len(nppes1)
# Out:
# 18717

# %%
len(nppes2)
# Out:
# 111

# %%
nppes2
# Out:
#             Entity Type Code Provider Organization Name (Legal Business Name)  \
# NPI
# 1710950183                 1                                              NaN
# 1740769413                 1                                              NaN
# 1164984100                 1                                              NaN
# 1497217442                 2                           HEALTHSTAT CLINICS LLC
# 1841752896                 1                                              NaN
# ...                      ...                                              ...
# 1952864084                 1                                              NaN
# 1265995302                 1                                              NaN
# 1841609351                 1                                              NaN
# 1902369085                 1                                              NaN
# 1649566977                 1                                              NaN
#
#            Provider Last Name (Legal Name) Provider First Name  \
# NPI
# 1710950183                 JIMENEZ MORALES                 LUZ
# 1740769413                   RIVERA TORRES             NOELLIE
# 1164984100                       LUGO JOSE             YADHIRA
# 1497217442                             NaN                 NaN
# 1841752896                              DU           XIAO ZHOU
# ...                                    ...                 ...
# 1952864084                        REICHMAN               JAMES
# 1265995302                            SURI              KARTIK
# 1841609351                         SANTANA             ABRAHAM
# 1902369085                      LUGO MUNOZ                JOSE
# 1649566977                FERNANDEZ SANTOS              CARLOS
#
#            Provider Middle Name          City      State
# NPI
# 1710950183                    M    SAN GERMAN         PR
# 1740769413                MARIE      SAN JUAN         PR
# 1164984100                  NaN         PONCE         PR
# 1497217442                  NaN     VEGA BAJA         PR
# 1841752896                  NaN      WINNIPEG         MB
# ...                         ...           ...        ...
# 1952864084                  NaN     JERUSALEM  JERUSALEM
# 1265995302                  RAJ       BURNABY         BC
# 1841609351                  NaN      SAN JUAN         PR
# 1902369085                 JUAN  SANTA ISABEL         PR
# 1649566977               JAVIER        CAGUAS         PR
#
# [111 rows x 7 columns]

# %%
nppes1[pd.isnull(nppes1['State'])]
# Out:
#             Entity Type Code Provider Organization Name (Legal Business Name)  \
# NPI
# 1225590060                 1                                              NaN
# 1649732488                 1                                              NaN
# 1235691015                 1                                              NaN
# 1609338318                 1                                              NaN
# 1841752532                 1                                              NaN
# 1184186736                 1                                              NaN
# 1780146365                 1                                              NaN
# 1124580600                 2                                 KHKN CORPORATION
# 1912469404                 1                                              NaN
# 1326500869                 1                                              NaN
# 1912469487                 1                                              NaN
# 1184720807                 1                                              NaN
# 1538621974                 1                                              NaN
# 1093277659                 1                                              NaN
# 1932661279                 1                                              NaN
# 1508328774                 1                                              NaN
# 1144782202                 1                                              NaN
# 1952864084                 1                                              NaN
#
#            Provider Last Name (Legal Name) Provider First Name  \
# NPI
# 1225590060                             NaN                 NaN
# 1649732488                             NaN                 NaN
# 1235691015                             NaN                 NaN
# 1609338318                             NaN                 NaN
# 1841752532                             NaN                 NaN
# 1184186736                             NaN                 NaN
# 1780146365                             NaN                 NaN
# 1124580600                             NaN                 NaN
# 1912469404                             NaN                 NaN
# 1326500869                             NaN                 NaN
# 1912469487                             NaN                 NaN
# 1184720807                             NaN                 NaN
# 1538621974                             NaN                 NaN
# 1093277659                             NaN                 NaN
# 1932661279                             NaN                 NaN
# 1508328774                             NaN                 NaN
# 1144782202                             NaN                 NaN
# 1952864084                             NaN                 NaN
#
#            Provider Middle Name City State
# NPI
# 1225590060                  NaN  NaN   NaN
# 1649732488                  NaN  NaN   NaN
# 1235691015                  NaN  NaN   NaN
# 1609338318                  NaN  NaN   NaN
# 1841752532                  NaN  NaN   NaN
# 1184186736                  NaN  NaN   NaN
# 1780146365                  NaN  NaN   NaN
# 1124580600                  NaN  NaN   NaN
# 1912469404                  NaN  NaN   NaN
# 1326500869                  NaN  NaN   NaN
# 1912469487                  NaN  NaN   NaN
# 1184720807                  NaN  NaN   NaN
# 1538621974                  NaN  NaN   NaN
# 1093277659                  NaN  NaN   NaN
# 1932661279                  NaN  NaN   NaN
# 1508328774                  NaN  NaN   NaN
# 1144782202                  NaN  NaN   NaN
# 1952864084                  NaN  NaN   NaN

# %%
combined = nppes1.combine_first(nppes2)

# %%
combined['State'].count()
# Out:
# 18717

# %%
len(nppes1)
# Out:
# 18717

# %%
combined.loc[1225590060]
# Out:
# Entity Type Code                                                1
# Provider Organization Name (Legal Business Name)              NaN
# Provider Last Name (Legal Name)                     ALICEA CASTRO
# Provider First Name                                          ERIC
# Provider Middle Name                                      GABRIEL
# City                                                    VEGA BAJA
# State                                                 PUERTO RICO
# Name: 1225590060, dtype: object

# %%
nppes1.loc[1225590060]
# Out:
# Entity Type Code                                      1
# Provider Organization Name (Legal Business Name)    NaN
# Provider Last Name (Legal Name)                     NaN
# Provider First Name                                 NaN
# Provider Middle Name                                NaN
# City                                                NaN
# State                                               NaN
# Name: 1225590060, dtype: object
