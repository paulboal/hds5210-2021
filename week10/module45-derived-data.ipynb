# %%
import pandas as pd

# %%
family = pd.DataFrame([
    ['Paul','E','Boal',193,110,'314-598-5494'],
    ['Teddy','J','Lester-Boal',101,23,'314-555-1234'],
    ['John','P','Doe',160,100,'490-982-5555']],
    columns=['First','Middle','Last','Height','Weight','Phone'])

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555

# %%
family['Full'] = family.First + ' ' + family.Middle + '. ' + family.Last

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full
# 0          Paul E. Boal
# 1  Teddy J. Lester-Boal
# 2           John P. Doe

# %%
family['Name'] = family.Last + ', ' + family.First + ' ' + family.Middle + '.'

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name
# 0          Paul E. Boal          Boal, Paul E.
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.
# 2           John P. Doe           Doe, John P.

# %%
family.sort_values('Name')
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 2   John      P          Doe     160     100  490-982-5555
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
#
#                    Full                   Name
# 0          Paul E. Boal          Boal, Paul E.
# 2           John P. Doe           Doe, John P.
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.

# %% [markdown]
# # Splitting

# %%
family['Area Code'] = family.Phone.str.split('-')

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name         Area Code
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]

# %%
family.Phone.str.split('-',expand=True)
# Out:
#      0    1     2
# 0  314  598  5494
# 1  314  555  1234
# 2  490  982  5555

# %%
family['Area'] = family.Phone.str.split('-',expand=True)[0]

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name         Area Code Area
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490

# %% [markdown]
# # Rank / Percentile

# %%
family.Height.rank()
# Out:
# 0    3.0
# 1    1.0
# 2    2.0
# Name: Height, dtype: float64

# %%
family['Height Rank'] = family.Height.rank()

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#    Height Rank
# 0          3.0
# 1          1.0
# 2          2.0

# %%
family['Height Pct'] = family.Height.rank(pct=True)

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#    Height Rank  Height Pct
# 0          3.0    1.000000
# 1          1.0    0.333333
# 2          2.0    0.666667

# %%
family.sort_values('Height Rank')
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
# 0   Paul      E         Boal     193     110  314-598-5494
#
#                    Full                   Name         Area Code Area  \
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
#
#    Height Rank  Height Pct
# 1          1.0    0.333333
# 2          2.0    0.666667
# 0          3.0    1.000000

# %% [markdown]
# # Arbitrary Functions

# %%
def bmi(vals):
    """Series -> float
    
    vals is a Pandas Series with two elements, Height and Weight
    
    """
    height = vals.Height
    weight = vals.Weight
    return weight / (height/100)**2

# %%
family[['Height','Weight']].apply(bmi, axis=1)
# Out:
# 0    29.530994
# 1    22.546809
# 2    39.062500
# dtype: float64

# %%
family['BMI'] = family[['Height','Weight']].apply(bmi, axis=1)

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#    Height Rank  Height Pct        BMI
# 0          3.0    1.000000  29.530994
# 1          1.0    0.333333  22.546809
# 2          2.0    0.666667  39.062500

# %%
family['BMI'].rank()
# Out:
# 0    2.0
# 1    1.0
# 2    3.0
# Name: BMI, dtype: float64

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone  \
# 0   Paul      E         Boal     193     110  314-598-5494
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234
# 2   John      P          Doe     160     100  490-982-5555
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#    Height Rank  Height Pct        BMI
# 0          3.0    1.000000  29.530994
# 1          1.0    0.333333  22.546809
# 2          2.0    0.666667  39.062500

# %%
def bmi(height, weight):
    """float, float -> float
    """
    return weight / (height/100)**2

# %%
family.apply(lambda x: bmi(x['Height'], x['Weight']), axis=1)
# Out:
# 0    29.530994
# 1    22.546809
# 2    39.062500
# dtype: float64
